# %% [markdown]
# # Homework 2
#
# ### Due Date: Friday, March 20
#
# ### Policy Gradient
#
# In this assignment, we will implement vanilla policy gradient algorithm (REINFORCE) covered in the lecture. You will work on i) a function approximator, ii) computing action, iii) collecting samples, iV) training the agent, V) plotting the resutls.
#
#
# ***Complete the missing operations and test your implemented algorithm on the Gym environment.***
#
# ***Software requirements:***
# - Python >= 3.6
# - Tensorflow version <= 1.15.3 (1.X version)
# - OpenAI Gym
#
# - Training the agent (policy) can take long time. It is recomended to start solving the problems earlier.
#
# - Save any plots you generated in this notebook. The grade will be given based on the plots you showed.

# %% [markdown]
# Make sure the packages you installed meet the requirements.

# %%
import tensorflow as tf
tf.__version__
# Out:
# '1.15.0'

# %%
import gym
gym.__version__
# Out:
# '0.18.0'

# %% [markdown]
# ## 1.1 Tensorflow Implementation
#
# We will be implementing policy gradient algorithm using Tensorflow 1.X., which simply updates the parameters of policy from obtaining gradient estimates. The core of policy gradient is to design a function approximator, computing actions, collecting samples, and training the policy. In the below cell, you are encouraged to fill in the components that are missing. ***Your tasks*** are
#
# 1. Complete the 'create_model' method to output the mean value for diagonal Guassian policy. Covariance is already defined in the model, so focus on creating neural network model.
#
# 2. Complete the 'action_op' method to calculate and return the actions for diagonal Gaussian policy. The applied action should be $\pi(s) = \pi_{\text{mean}}(s) + exp(logstd) * \mathcal{N}(0,1)$
#
# ***Hints***:
# - Some useful tensorflow classes and methods include: 'tf.exp', 'tf.random_normal'

# %% [markdown]
# ***IF you are using MAC, please run below box***

# %%
import os
# MAC user only
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
import tensorflow as tf
import numpy as np
import os
import ipdb


class PolicyOpt(object):

    def __init__(self, env, linear=False, stochastic=True, hidden_size=32, nonlinearity=tf.nn.relu):
        """Instantiate the policy iteration class.

        This initializes the policy optimization with a set of trainable 
        parameters, and creates a tensorflow session.

        Attributes
        ----------
        env : gym.Env
            the environment that the policy will be trained on
        linear : bool, optional
            specifies whether to use a linear or neural network 
            policy, defaults to False (i.e. Fully-Connected-Neural-Network)
        stochastic : bool, optional
            specifies whether to use a stochastic or deterministic 
            policy, defaults to True
        hidden_size : list of int, optional
            list of hidden layers, with each value corresponding 
            to the number of nodes in that layer 
        nonlinearity : tf.nn.*
            activation nonlinearity
        """
        
        # clear computation graph
        tf.reset_default_graph()
        
        # set a random seed
        tf.set_random_seed(1234)
        
        # start a tensorflow session
        self.sess = tf.Session()
        
        # environment to train on
        self.env = env
        
        # number of elements in the action space
        self.ac_dim = env.action_space.shape[0]
        
        # number of elements in the observation space
        self.obs_dim = env.observation_space.shape[0]

        # actions placeholder
        self.a_t_ph = tf.placeholder(dtype=tf.float32, 
                                     shape=[None, self.ac_dim])
        # state placeholder
        self.s_t_ph = tf.placeholder(dtype=tf.float32, 
                                     shape=[None, self.obs_dim])
        # expected reward placeholder
        self.rew_ph = tf.placeholder(dtype=tf.float32, 
                                     shape=[None])

        # specifies whether the policy is stochastic
        self.stochastic = stochastic

        # policy that the agent executes during training/testing
        self.policy = self.create_model(
            args={
                "num_actions": self.ac_dim,
                "hidden_size": hidden_size,
                "linear": linear,
                "nonlinearity": nonlinearity,
                "stochastic": stochastic,
                "scope": "policy",
            }
        )
        
        # define symbolic action
        self.symbolic_action = self.action_op()

        # initialize all variables
        self.sess.run(tf.global_variables_initializer())

        # create saver to save model variables
        self.saver = tf.train.Saver()

    def create_model(self, args):
        """Create a model for your policy or other components.

        Parameters
        ----------
        args : dict
            model-specific arguments, with keys:
              - "stochastic": True by default
              - "hidden_size": Number of neurons in hidden layer
              - "num_actions" number of output actions
              - "scope": scope of the model

        Returns
        -------
        tf.Variable
            mean actions of the policy
        tf.Variable 
            logstd of the policy actions
        """

#################### Build Your Neural Network Here! ####################  

        layer_1 = tf.layers.dense(self.s_t_ph, args["hidden_size"], activation=args["nonlinearity"])
        layer_2 = tf.layers.dense(layer_1, 50, activation=tf.nn.relu)
        output_mean = tf.layers.dense(layer_2, args["num_actions"])  

        
##########################################################################        

        if args["stochastic"]:
            output_logstd =  tf.get_variable(name="action_logstd",shape=[self.ac_dim],trainable=True)
        else:
            output_logstd = None

        return output_mean, output_logstd
    
    def action_op(self):
        """
        Create a symbolic expression that will be used to compute actions from observations.

        When the policy is stochastic, the action follows 

            a_t = output_mean + exp(output_logstd) * z; z ~ N(0,1)
        """
        if self.stochastic:
            output_mean, output_logstd = self.policy

            #################### Implement a stochastic policy here ####################        
            # Implement a stochastic version of computing actions.       #
            #                                                            #
            # The action in a stochastic policy represented by           #
            # a diagonal Gaussian distribution with mean "M" and log     #
            # standard deviation "logstd" is computed as follows:        #
            #                                                            #
            #     a = M + exp(logstd) * z                                #
            #                                                            #
            # where z is a random normal value, i.e. z ~ N(0,1)          #
            #                                                            #
            # In order to generate numbers from a normal distribution,   #
            # use the `tf.random_normal` function.                       #
            ############################################################################ 
            symbolic_action = output_mean+tf.math.exp(output_logstd)*tf.random_normal([1])
            
        else:
            symbolic_action, _ = self.policy
        
        return symbolic_action

    def compute_action(self, obs):
        """Returns a list of actions for a given observation.

        Parameters
        ----------
        obs : np.ndarray
            observations

        Returns
        -------
        np.ndarray
            actions by the policy for a given observation
        """
        return self.sess.run(self.symbolic_action,feed_dict={self.s_t_ph: obs})

    def rollout(self, s_mean=None, s_std=None):
        """Collect samples from one rollout of the policy.

        Returns
        -------
        dict
            dictionary containing trajectory information for the rollout,
            specifically containing keys for "state", "action", "next_state", "reward", and "done"
        """
        states = []
        next_states = []
        actions = []
        rewards = []
        dones = []

        # start a new rollout by re-setting the environment and collecting the initial state
        state =  self.env.reset()

        steps = 0
        while True:
            steps += 1

            # compute the action given the state
            if s_mean is not None and s_std is not None:
                action = self.compute_action([(state - s_mean) / s_std])
            else:
                action = self.compute_action([state])
            action = action[0]

            # advance the environment once and collect the next state, reward, done, and info parameters from the environment
            next_state, reward, done, info =  self.env.step(action)

            # add to the samples list
            states.append(state)
            actions.append(action)
            next_states.append(next_state)
            rewards.append(reward)
            dones.append(done)

            state = next_state

            # if the environment returns a True for the done parameter,
            # end the rollout before the time horizon is met
            if done or steps > env._max_episode_steps:
                break

        # create the output trajectory
        trajectory = {"state": np.array(states, dtype=np.float32),
                      "reward": np.array(rewards, dtype=np.float32),
                      "action": np.array(actions, dtype=np.float32),
                      "next_state": np.array(next_states, dtype=np.float32),
                      "done": np.array(dones, dtype=np.float32)}

        return trajectory

    def train(self, args):
        """Abstract training method.

        This method will be filled in by algorithm-specific
        training operations in subsequent problems.

        Parameters
        ----------
        args : dict
            algorithm-specific hyperparameters
        """
        raise NotImplementedError

# %% [markdown]
# ## 1.2 Tensorflow Interpretation
#
# In order to test your implementation of the **stochastic policy**, run the below cell. The task is to interpret the code you implemented in previous section. If you implement correctly, you can see the value_1 and value_2.
#
# ***Question: How do you interpret value_1 and value_2 below cell?***

# %%
import gym
TEST_ENV = gym.make("Pendulum-v0")

alg = PolicyOpt(TEST_ENV, linear=False)
input_1 = [[0, 1, 2]]
value_1 = alg.sess.run(alg.policy[1], feed_dict={alg.s_t_ph: input_1})
value_2 = alg.compute_action(input_1)
# Out:
# WARNING:tensorflow:From <ipython-input-4-a64d538fa09d>:106: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# WARNING:tensorflow:From /home/chriswvu/anaconda3/envs/reinforcement_learning/lib/python3.6/site-packages/tensorflow_core/python/layers/core.py:187: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.

# %%
TEST_ENV.env.action_space
# Out:
# Box(-2.0, 2.0, (1,), float32)

# %% [markdown]
# Answer:

# %%
value_2
# Out:
# array([[0.24253109]], dtype=float32)

# %% [markdown]
# Answer:

# %% [markdown]
# ## 1.3 Implement Policy Gradient
#
# In this section, we will implement REINFORCE algorithm presented in the lecture. As a review, the objective is optimize the parameters $\theta$ of some policy $\pi_\theta$ so that the expected return
#
# \begin{equation}
# J(\theta) = \mathbb{E} \bigg\{ \sum_{t=0}^T \gamma^t r(s_{t},a_{t}) \bigg\}
# \end{equation}
#
# is optimized. In this algorithm, this is done by calculating the gradient $\nabla_\theta J$ and applying a gradient descent method to find a better policy.
#
# \begin{equation}
# \theta ' = \theta + \alpha \nabla_\theta J(\theta)
# \end{equation}
#
# In the lecture, we derive how we compute $\nabla_{\theta} J(\theta)$. We can rewrite our policy gradient as:
#
# \begin{equation}
# \nabla_\theta J (\theta) \approx \frac{1}{N} \sum_{i=0}^{N} \bigg( \sum_{t=0}^{T} \nabla_\theta \log \pi_\theta (a_{it} | s_{it}) \bigg) \bigg( \sum_{t=0}^T \gamma^{t}r_i(t) \bigg)
# \end{equation}
#
# Finally, taking into account the causality principle discussed in class, we are able to simplifiy the gradient estimate such as:
#
# \begin{equation}
# \nabla_\theta J (\theta) \approx \frac{1}{N} \sum_{i=0}^{N} \sum_{t=0}^{T} \nabla_\theta \log \pi_\theta (a_{it} | s_{it}) \sum_{t'=t}^T \gamma^{t'-t}r_i(t')
# \end{equation}
#
# You will be implementing final expression in this assignment!

# %% [markdown]
# The process of REINFOCE algorithm follows:
#
# 1. Collect samples from current policy $\pi_\theta(s)$ by executing rollouts of the environment.
# 2. Calculate an estimate for the expected return at state $s_t$.
# 3. Compute the log-likelihood of each action that was performed by the policy at every given step.
# 4. Estimate the gradient and update the parameters of policy using gradient-based technique.
# 5. Repeat steps 1-4 for a number of training iterations.
#
# ***Your task*** is to fill out the skeleton code for REINFORCE algorithm,
#
# 1. Complete the 'log_likelihoods' method to compute gradient of policy, $\nabla_{\theta}\pi_{\theta}$ for diagonal Guassian policy.
#
# 2. Complete the 'compute_expected_return' method to calculate the reward-to-go, $\sum_{t^{\prime}=t}^{T}$.

# %%
import tensorflow as tf
import numpy as np
import time
import tensorflow_probability as tfp

class REINFORCE(PolicyOpt):

    def train(self, num_iterations=1000, steps_per_iteration=1000, learning_rate=int(1e-4), gamma=0.95, 
              **kwargs):
        """Perform the REINFORE training operation.

        Parameters
        ----------
        num_iterations : int
            number of training iterations
        steps_per_iteration : int
            number of individual samples collected every training iteration
        learning_rate : float
            optimizer learning rate
        gamma : float
            discount rate
        kwargs : dict
            additional arguments

        Returns
        -------
        list of float
            average return per iteration
        """
        # set the discount as an attribute
        self.gamma = gamma
        
        # set the learning rate as an attribute
        self.learning_rate = learning_rate

        # create a symbolic expression to compute the log-likelihoods 
        log_likelihoods = self.log_likelihoods()

        # create a symbolic expression for updating the parameters of your policy
        self.opt, self.opt_baseline = self.define_updates(log_likelihoods)
        
        # initialize all variables
        self.sess.run(tf.global_variables_initializer())


        # average return per training iteration
        ret_per_iteration = []
        
        samples = []
        for i in range(num_iterations):
            
            # collect samples from the current policy
            samples.clear()
            steps_so_far = 0
            while steps_so_far < steps_per_iteration:
                new_samples = self.rollout()
                steps_so_far += new_samples["action"].shape[0]
                samples.append(new_samples)

            # compute the expected returns
            v_s = self.compute_expected_return(samples)

            # compute and apply the gradients
            self.call_updates(log_likelihoods, samples, v_s, **kwargs)

            # compute the average cumulative return per iteration
            average_rew = np.mean([sum(s["reward"]) for s in samples])

            # display iteration statistics
            print("Iteration {} return: {}".format(i, average_rew))
            ret_per_iteration.append(average_rew)

        return ret_per_iteration

    def log_likelihoods(self):
        """Create a tensorflow operation that computes the log-likelihood 
        of each performed action.
        """
        
        output_mean, output_logstd = self.policy

        ##############################################################
        # Create a tf operation to compute the log-likelihood of     #
        # each action that was performed by the policy               #
        #                                                            #
        # The log likelihood in the continuous case where the policy #
        # is expressed by a multivariate gaussian can be computing   #
        # using the tensorflow object:                               #
        #                                                            #
        #    p = tfp.distributions.MultivariateNormalDiag(           #
        #        loc=...,                                            #
        #        scale_diag=...,                                     #
        #    )                                                       #
        #                                                            #
        # This method takes as input a mean (loc) and standard       #
        # deviation (scale_diag), and then can be used to compute    #
        # the log-likelihood of a variable as follows:               #
        #                                                            #
        #    log_likelihoods = p.log_prob(...)                       #
        #                                                            #
        # For this operation, you will want to use placeholders      #
        # created in the __init__ method of problem 1.               #
        ##############################################################

        p = tfp.distributions.MultivariateNormalDiag(           
                loc=output_mean, scale_diag=output_logstd)
        log_likelihoods = p.log_prob(self.a_t_ph)

        return log_likelihoods

    def compute_expected_return(self, samples):
        """Compute the expected return from a given starting state.
        This is done by using the reward-to-go method.

        Parameters
        ----------
        rewards : list of list of float
            a list of N trajectories, with each trajectory contain T 
            returns values (one for each step in the trajectory)

        Returns
        -------
        list of float, or np.ndarray
            expected returns for each step in each trajectory
        """
        rewards = [s["reward"] for s in samples]
        ##############################################################
        # Estimate the expected return from any given starting state #
        # using the reward-to-go method.                             #
        #                                                            #
        # Using this method, the reward is estimated at every step   #
        # of the trajectory as follows:                              #
        #                                                            #
        #   r = sum_{t'=t}^T gamma^(t'-t) * r_{t'}                   #
        #                                                            #
        # where T is the time horizon at t is the index of the       #
        # current reward in the trajectory. For example, for a given #
        # set of rewards r = [1,1,1,1] and discount rate gamma = 1,  #
        # the expected reward-to-go would be:                        #
        #                                                            #
        #   v_s = [4, 3, 2, 1]                                       #
        #                                                            #
        # You will be able to test this in one of the cells below!   #
        ##############################################################
        #v_s = [5,3,2,1]
        #vs = [r*(len(reward)-i)*pow(gamma,(len(rewards)-i)) for i,r in enumerate(rewards)]
        v_s = [sum(r[i:])*pow(self.gamma,(len(rewards)-i)) for r in rewards for i in range(len(r))]
        return v_s

    def define_updates(self, log_likelihoods):
        """Create a tensorflow operation to update the parameters of 
        your policy.

        Parameters
        ----------
        log_likelihoods : tf.Operation
            the symbolic expression you created to estimate the log 
            likelihood of a set of actions

        Returns
        -------
        tf.Operation
            a tensorflow operation for computing and applying the 
            gradients to the parameters of the policy
        None
            the second component is used in problem 2.b, please ignore 
            for this problem
        """

        loss = - tf.reduce_mean(tf.multiply(log_likelihoods, self.rew_ph))
        opt = tf.train.AdamOptimizer(self.learning_rate).minimize(loss)

        return opt, None

    def call_updates(self, log_likelihoods, samples, v_s, **kwargs):
        """Apply the gradient update methods in a tensorflow session.

        Parameters
        ----------
        log_likelihoods: tf.Operation
            the symbolic expression you created to estimate the log 
            likelihood of a set of actions
        samples : list of dict
            a list of N trajectories, with each trajectory containing 
            a dictionary of trajectory data (see self.rollout)
        v_s : list of float, or np.ndarray
            the estimated expected returns from your
            `comput_expected_return` function 
        kwargs : dict
            additional arguments (used in question 3)
        """
        # concatenate the states
        states = np.concatenate([s["state"] for s in samples])

        # concatenate the actions
        actions = np.concatenate([s["action"] for s in samples])

        # execute the optimization step
        self.sess.run(self.opt, feed_dict={self.s_t_ph: states,
                                           self.a_t_ph: actions,
                                           self.rew_ph: v_s})

# %% [markdown]
# Check your 'log_likelihoods' method by running below cell:

# %%
alg = REINFORCE(TEST_ENV, stochastic=True)

log_likelihoods = alg.log_likelihoods()

# collect a sample output for a given input state
input_s = [[0, 0, 0], [0, 1, 2], [1, 2, 3]]
input_a = [[0], [1], [2]]

# Check
computed = alg.sess.run(log_likelihoods, feed_dict={alg.a_t_ph: input_a, alg.s_t_ph: input_s})

# %%
computed
# Out:
# array([-0.8827907, -1.0238237, -1.3920786], dtype=float32)

# %% [markdown]
# Test your 'compute_expected_return' by running below cell:

# %%
# 1. Test the non-normalized case
alg = REINFORCE(TEST_ENV, stochastic=True)
alg.gamma = 1.0
    
input_1 = [{"reward": [1, 1, 1, 1]},
           {"reward": [1, 1, 1, 1]}]
vs_1 = alg.compute_expected_return(samples=input_1)
ans_1 = np.array([4, 3, 2, 1, 4, 3, 2, 1])

if np.linalg.norm(vs_1 - ans_1) < 1e-3:
    print('Great job!')
else:
    print('Check your implementation (compute_expected_return)')
# Out:
# Great job!

# %% [markdown]
# ## 1.4 Testing your algorithm
#
# When you are ready, test your policy gradient algorithms on the *Pendulum-v0* environment in the cell below. *Pendulum-v0* environment is similar to *off-shore wind power*, the goal here is to maintain the Pendulum is upright using control input. The best policy should get around -200 scores. ***Your task*** is to run your REINFORCE algorithm and plot the result!

# %%
# set this number as 1 for testing your algorithm, and 3 for plotting
NUM_TRIALS = 3

# ===========================================================================
# Do not modify below line
# ===========================================================================

# we will test the algorithms on the Pendulum-v0 gym environment
import gym
env = gym.make("Pendulum-v0")

# train on the REINFORCE algorithm
import numpy as np
r = []
for i in range(NUM_TRIALS):
    print("\n==== Training Run {} ====".format(i))
    alg = REINFORCE(env, stochastic=True)
    res = alg.train(learning_rate=0.005, gamma=0.95, num_iterations=500, steps_per_iteration=15000)
    r.append(np.array(res))
    alg = None

# save results
np.savetxt("InvertedPendulum_results.csv", np.array(r), delimiter=",")
# Out:
# ==== Training Run 0 ====
# Iteration 0 return: -1250.6426841695607
# Iteration 1 return: -1140.2230289396518
# Iteration 2 return: -1109.7723370533056
# Iteration 3 return: -1147.1293808423106
# Iteration 4 return: -1156.0942307918099
# Iteration 5 return: -1149.0448403058379
# Iteration 6 return: -1135.6469043124218
# Iteration 7 return: -1166.807921275068
# Iteration 8 return: -1163.5457119794298
# Iteration 9 return: -1145.0513377646296
# Iteration 10 return: -1176.422530351424
# Iteration 11 return: -1184.3164525238549
# Iteration 12 return: -1136.8767126731263
# Iteration 13 return: -1158.8047559186443
# Iteration 14 return: -1166.5381146606337
# Iteration 15 return: -1128.9804771378979
# Iteration 16 return: -1150.9142264323095
# Iteration 17 return: -1125.6936555994769
# Iteration 18 return: -1157.5958686106985
# Iteration 19 return: -1133.9703269950517
# Iteration 20 return: -1172.2130679867928
# Iteration 21 return: -1150.9238949426513
# Iteration 22 return: -1157.8235940697084
# Iteration 23 return: -1129.5229863186476
# Iteration 24 return: -1117.3730334961895
# Iteration 25 return: -1160.9183152840567
# Iteration 26 return: -1191.4740651983363
# Iteration 27 return: -1154.2462752513743
# Iteration 28 return: -1137.762260939479
# Iteration 29 return: -1119.972023323498
# Iteration 30 return: -1134.238398524231
# Iteration 31 return: -1145.7721763771865
# Iteration 32 return: -1078.9699954006371
# Iteration 33 return: -1081.4111000064295
# Iteration 34 return: -1060.2482994511415
# Iteration 35 return: -1088.4030227634814
# Iteration 36 return: -1098.0829689908687
# Iteration 37 return: -1072.0769460101853
# Iteration 38 return: -1096.5703978741976
# Iteration 39 return: -1044.0399848488687
# Iteration 40 return: -1037.4532423910498
# Iteration 41 return: -1044.192935516429
# Iteration 42 return: -1048.626550968384
# Iteration 43 return: -1103.0789707139725
# Iteration 44 return: -1099.8375052380904
# Iteration 45 return: -1149.1027882847284
# Iteration 46 return: -1161.8867453345595
# Iteration 47 return: -1148.4736151811278
# Iteration 48 return: -1164.4859319899665
# Iteration 49 return: -1180.429605767918
# Iteration 50 return: -1162.863970170316
# Iteration 51 return: -1140.2813356744778
# Iteration 52 return: -1152.0099677343976
# Iteration 53 return: -1089.6872698509756
# Iteration 54 return: -1123.0510948948377
# Iteration 55 return: -1126.8195776727982
# Iteration 56 return: -1070.6020153963939
# Iteration 57 return: -1087.874878087303
# Iteration 58 return: -1078.7744324703965
# Iteration 59 return: -1079.8321605956517
# Iteration 60 return: -1065.1991661978257
# Iteration 61 return: -1070.1666828869515
# Iteration 62 return: -1090.5645662492545
# Iteration 63 return: -1108.2318226098114
# Iteration 64 return: -1109.2899483693468
# Iteration 65 return: -1114.5414996261584
# Iteration 66 return: -1091.6501808880573
# Iteration 67 return: -1083.1751682830939
# Iteration 68 return: -1083.4322731229602
# Iteration 69 return: -1062.7259631822662
# Iteration 70 return: -1050.525489381125
# Iteration 71 return: -1109.4229884885376
# Iteration 72 return: -1079.2876826622212
# Iteration 73 return: -1068.366331312315
# Iteration 74 return: -1052.097996190343
# Iteration 75 return: -1040.3616248506758
# Iteration 76 return: -1050.299268048651
# Iteration 77 return: -1090.855291897754
# Iteration 78 return: -1107.515021645883
# Iteration 79 return: -1050.117435003342
# Iteration 80 return: -1032.0637650001358
# Iteration 81 return: -993.8542187714025
# Iteration 82 return: -1030.979264813851
# Iteration 83 return: -998.4450645986703
# Iteration 84 return: -993.9801441437995
# Iteration 85 return: -1041.9717577360477
# Iteration 86 return: -1023.9840533104182
# Iteration 87 return: -965.7232594631276
# Iteration 88 return: -930.5414453067355
# Iteration 89 return: -1016.7258159309191
# Iteration 90 return: -995.7145842999903
# Iteration 91 return: -1000.8134416074136
# Iteration 92 return: -1007.1957313147824
# Iteration 93 return: -992.0065614317878
# Iteration 94 return: -968.9648866288865
# Iteration 95 return: -947.3810583645742
# Iteration 96 return: -976.7911960112319
# Iteration 97 return: -967.7659657903544
# Iteration 98 return: -970.6781688186517
# Iteration 99 return: -905.2791771993941
# Iteration 100 return: -881.6589561980055
# Iteration 101 return: -892.2115977994415
# Iteration 102 return: -833.6881327158444
# Iteration 103 return: -861.0948962394148
# Iteration 104 return: -871.2266813853279
# Iteration 105 return: -872.5161932246468
# Iteration 106 return: -880.3538502420377
# Iteration 107 return: -893.9129952237212
# Iteration 108 return: -868.9950824958428
# Iteration 109 return: -826.5351253655662
# Iteration 110 return: -831.8396941895271
# Iteration 111 return: -852.3573628459269
# Iteration 112 return: -805.5814224356851
# Iteration 113 return: -756.2373014929829
# Iteration 114 return: -720.7099108237393
# Iteration 115 return: -718.6961327602592
# Iteration 116 return: -686.1632257727623
# Iteration 117 return: -651.3708863559237
# Iteration 118 return: -662.6587808453278
# Iteration 119 return: -611.5157856717681
# Iteration 120 return: -635.171023377776
# Iteration 121 return: -622.9177505506804
# Iteration 122 return: -615.6189504418037
# Iteration 123 return: -607.8231105953067
# Iteration 124 return: -642.708310315414
# Iteration 125 return: -643.8228599708585
# Iteration 126 return: -590.8021009689459
# Iteration 127 return: -505.0487282427509
# Iteration 128 return: -482.81871896378385
# Iteration 129 return: -437.21856921105217
# Iteration 130 return: -401.9562539188248
# Iteration 131 return: -408.41887305255466
# Iteration 132 return: -367.33848785513635
# Iteration 133 return: -313.51788493780333
# Iteration 134 return: -285.96443797783536
# Iteration 135 return: -310.7990859082799
# Iteration 136 return: -278.30881025251233
# Iteration 137 return: -272.92834321612145
# Iteration 138 return: -262.8564624036215
# Iteration 139 return: -251.95462268697258
# Iteration 140 return: -248.13581649597947
# Iteration 141 return: -243.47545801020814
# Iteration 142 return: -250.70113774752278
# Iteration 143 return: -247.98234339746315
# Iteration 144 return: -260.29325221012976
# Iteration 145 return: -256.7820436367327
# Iteration 146 return: -259.70057924571626
# Iteration 147 return: -272.25675835157847
# Iteration 148 return: -288.25601151465
# Iteration 149 return: -225.27315040056428
# Iteration 150 return: -236.03207133622868
# Iteration 151 return: -265.69006097642364
# Iteration 152 return: -289.37816418009936
# Iteration 153 return: -231.08208470349956
# Iteration 154 return: -220.6375917855625
# Iteration 155 return: -244.142248903501
# Iteration 156 return: -243.35508796493434
# Iteration 157 return: -236.95358863728373
# Iteration 158 return: -227.71753984397063
# Iteration 159 return: -232.83813426989906
# Iteration 160 return: -242.60417820133583
# Iteration 161 return: -283.3601692348215
# Iteration 162 return: -229.91233720942537
# Iteration 163 return: -274.21783887404035
# Iteration 164 return: -253.43744347708713
# Iteration 165 return: -284.31711838593867
# Iteration 166 return: -265.9177457578163
# Iteration 167 return: -210.35811960606233
# Iteration 168 return: -220.40941443797726
# Iteration 169 return: -235.62949563634416
# Iteration 170 return: -246.64135287356257
# Iteration 171 return: -256.35584882709054
# Iteration 172 return: -230.6198359376927
# Iteration 173 return: -233.60831541606336
# Iteration 174 return: -229.66432326399226
# Iteration 175 return: -266.8825761253504
# Iteration 176 return: -248.05669926325058
# Iteration 177 return: -237.05405439748864
# Iteration 178 return: -244.5252900854335
# Iteration 179 return: -229.19345327842913
# Iteration 180 return: -233.39827463945315
# Iteration 181 return: -257.280290901273
# Iteration 182 return: -274.8363617447607
# Iteration 183 return: -264.83563296483277
# Iteration 184 return: -221.44432778535892
# Iteration 185 return: -259.65446046388126
# Iteration 186 return: -199.6671642976955
# Iteration 187 return: -275.3233809204461
# Iteration 188 return: -268.3548787291843
# Iteration 189 return: -280.6161321711377
# Iteration 190 return: -277.47203966665154
# Iteration 191 return: -234.74706196986642
# Iteration 192 return: -246.41137483723375
# Iteration 193 return: -233.2281666761237
# Iteration 194 return: -216.90277718696262
# Iteration 195 return: -274.9383784174829
# Iteration 196 return: -257.21501732074944
# Iteration 197 return: -262.9766390462042
# Iteration 198 return: -254.82692263567392
# Iteration 199 return: -253.33908945923991
# Iteration 200 return: -256.97541554668317
# Iteration 201 return: -234.82526867013632
# Iteration 202 return: -226.37076307638372
# Iteration 203 return: -264.4791654865833
# Iteration 204 return: -269.40698351784175
# Iteration 205 return: -209.29476021223252
# Iteration 206 return: -255.83390959263247
# Iteration 207 return: -254.20742352660082
# Iteration 208 return: -223.64780052528965
# Iteration 209 return: -271.82660613195316
# Iteration 210 return: -245.76449441606383
# Iteration 211 return: -245.96929444666563
# Iteration 212 return: -273.5828041632195
# Iteration 213 return: -234.3729962908029
# Iteration 214 return: -262.9612759970059
# Iteration 215 return: -258.09965093196854
# Iteration 216 return: -225.72845830853058
# Iteration 217 return: -255.82456993484539
# Iteration 218 return: -245.11363260692588
# Iteration 219 return: -208.5560137183908
# Iteration 220 return: -298.76241915884316
# Iteration 221 return: -245.84065937146582
# Iteration 222 return: -243.75331977886108
# Iteration 223 return: -265.3511545870328
# Iteration 224 return: -245.09836487743857
# Iteration 225 return: -222.36465059433837
# Iteration 226 return: -265.4540318873286
# Iteration 227 return: -296.1910408548655
# Iteration 228 return: -278.6594869452741
# Iteration 229 return: -266.46189577911485
# Iteration 230 return: -235.0075286557506
# Iteration 231 return: -244.1157401614515
# Iteration 232 return: -263.9417703992488
# Iteration 233 return: -270.3355816276924
# Iteration 234 return: -243.1862116693766
# Iteration 235 return: -215.44304054096844
# Iteration 236 return: -267.51527284834077
# Iteration 237 return: -257.5705451325928
# Iteration 238 return: -284.54973109374527
# Iteration 239 return: -225.9840352485866
# Iteration 240 return: -233.53422261239484
# Iteration 241 return: -216.57422374102873
# Iteration 242 return: -241.34778125368436
# Iteration 243 return: -248.36314928485245
# Iteration 244 return: -236.45823997245472
# Iteration 245 return: -287.70941364694477
# Iteration 246 return: -241.90723740715393
# Iteration 247 return: -230.8671908812597
# Iteration 248 return: -254.00347021916096
# Iteration 249 return: -251.38159434762827
# Iteration 250 return: -265.1910449262668
# Iteration 251 return: -240.03232022758039
# Iteration 252 return: -253.44908974202932
# Iteration 253 return: -229.60037665587473
# Iteration 254 return: -234.830881321184
# Iteration 255 return: -253.91878396497268
# Iteration 256 return: -266.27222265837406
# Iteration 257 return: -232.40803849715246
# Iteration 258 return: -259.94959427258897
# Iteration 259 return: -260.86760673820646
# Iteration 260 return: -266.36401109189427
# Iteration 261 return: -235.96627590756486
# Iteration 262 return: -250.17697741352225
# Iteration 263 return: -254.46950285044014
# Iteration 264 return: -239.64542416499904
# Iteration 265 return: -277.16797941386557
# Iteration 266 return: -246.76116044854933
# Iteration 267 return: -247.89035823695133
# Iteration 268 return: -252.23588908455307
# Iteration 269 return: -251.3561860406475
# Iteration 270 return: -212.2728713603051
# Iteration 271 return: -204.34136289724492
# Iteration 272 return: -240.03055166548893
# Iteration 273 return: -245.26859771723724
# Iteration 274 return: -261.1470382143499
# Iteration 275 return: -217.94371252350416
# Iteration 276 return: -231.71846067813564
# Iteration 277 return: -241.7121515684112
# Iteration 278 return: -228.15686487146672
# Iteration 279 return: -224.09634274345018
# Iteration 280 return: -239.7638421002516
# Iteration 281 return: -259.366059500206
# Iteration 282 return: -230.28703015948375
# Iteration 283 return: -257.2861485998859
# Iteration 284 return: -259.2802924962928
# Iteration 285 return: -246.07660566900012
# Iteration 286 return: -226.7112738850025
# Iteration 287 return: -259.2938423336109
# Iteration 288 return: -249.77154279576004
# Iteration 289 return: -221.6049523374884
# Iteration 290 return: -253.85561663077573
# Iteration 291 return: -262.70437671230303
# Iteration 292 return: -254.94140168096632
# Iteration 293 return: -259.12669127600503
# Iteration 294 return: -241.73974956202767
# Iteration 295 return: -270.7235478435884
# Iteration 296 return: -266.4393831432037
# Iteration 297 return: -287.73015970994834
# Iteration 298 return: -262.8248715322487
# Iteration 299 return: -237.0387428828869
# Iteration 300 return: -265.2545220263124
# Iteration 301 return: -231.85173251840428
# Iteration 302 return: -246.61656001011832
# Iteration 303 return: -270.32862799805235
# Iteration 304 return: -218.88683830865125
# Iteration 305 return: -226.03831655162057
# Iteration 306 return: -192.0160275902607
# Iteration 307 return: -237.97972999414176
# Iteration 308 return: -263.82519077705024
# Iteration 309 return: -253.7376074213019
# Iteration 310 return: -205.49036874557765
# Iteration 311 return: -240.93694940394658
# Iteration 312 return: -240.45145941633885
# Iteration 313 return: -233.9939806997376
# Iteration 314 return: -272.66874907285796
# Iteration 315 return: -209.12187491718421
# Iteration 316 return: -242.24141810619074
# Iteration 317 return: -231.18451472452134
# Iteration 318 return: -241.22333633643402
# Iteration 319 return: -206.67489254204185
# Iteration 320 return: -204.16958096063885
# Iteration 321 return: -244.10373494591263
# Iteration 322 return: -235.92236066966748
# Iteration 323 return: -235.2447687956519
# Iteration 324 return: -266.2721130510572
# Iteration 325 return: -281.87708205494414
# Iteration 326 return: -223.3244964861034
# Iteration 327 return: -238.58334771868138
# Iteration 328 return: -250.63047059186258
# Iteration 329 return: -225.76879721744152
# Iteration 330 return: -218.90001630834115
# Iteration 331 return: -202.16712764951842
# Iteration 332 return: -237.07120842252493
# Iteration 333 return: -264.9087728049701
# Iteration 334 return: -256.1241449651562
# Iteration 335 return: -270.32846774616434
# Iteration 336 return: -258.9722199532279
# Iteration 337 return: -222.7561947208801
# Iteration 338 return: -273.8452649820405
# Iteration 339 return: -203.98931720340522
# Iteration 340 return: -257.00629895422503
# Iteration 341 return: -208.79082757056636
# Iteration 342 return: -253.14896082633814
# Iteration 343 return: -224.01417765557844
# Iteration 344 return: -224.84238599660466
# Iteration 345 return: -225.83191104081334
# Iteration 346 return: -228.78934711076917
# Iteration 347 return: -225.96729223595204
# Iteration 348 return: -241.8159179618436
# Iteration 349 return: -209.11919696405303
# Iteration 350 return: -264.6134987280221
# Iteration 351 return: -224.15913454350667
# Iteration 352 return: -240.53027722107296
# Iteration 353 return: -211.63115055366399
# Iteration 354 return: -209.77576563840998
# Iteration 355 return: -213.48228886876615
# Iteration 356 return: -229.89815007379818
# Iteration 357 return: -235.55826058708365
# Iteration 358 return: -203.8159171389629
# Iteration 359 return: -255.1353730190745
# Iteration 360 return: -225.77054348623923
# Iteration 361 return: -229.05890347530624
# Iteration 362 return: -256.19990261265957
# Iteration 363 return: -234.61743415250447
# Iteration 364 return: -244.5326070814688
# Iteration 365 return: -276.723183959429
# Iteration 366 return: -241.7736345409411
# Iteration 367 return: -237.69749240092915
# Iteration 368 return: -220.6066240888767
# Iteration 369 return: -216.85964729791385
# Iteration 370 return: -234.18519871384103
# Iteration 371 return: -238.42602189955107
# Iteration 372 return: -232.03022212724866
# Iteration 373 return: -229.07505527477713
# Iteration 374 return: -224.59636799322794
# Iteration 375 return: -268.35083875261677
# Iteration 376 return: -213.81316443948646
# Iteration 377 return: -237.98377642860817
# Iteration 378 return: -239.7082057788709
# Iteration 379 return: -235.49195556129072
# Iteration 380 return: -228.84415809234503
# Iteration 381 return: -214.93135905603197
# Iteration 382 return: -201.76007133329009
# Iteration 383 return: -217.69978741006014
# Iteration 384 return: -231.66398052542064
# Iteration 385 return: -213.22996662775336
# Iteration 386 return: -230.57504357285927
# Iteration 387 return: -231.57736385594976
# Iteration 388 return: -232.69962228598627
# Iteration 389 return: -213.01776308306543
# Iteration 390 return: -218.85311024243947
# Iteration 391 return: -245.00636788730125
# Iteration 392 return: -255.10760157158762
# Iteration 393 return: -201.4539088587719
# Iteration 394 return: -207.61504302558382
# Iteration 395 return: -184.20382463818277
# Iteration 396 return: -262.4183931739859
# Iteration 397 return: -247.00103192973737
# Iteration 398 return: -207.96965275588082
# Iteration 399 return: -209.52748868723847
# Iteration 400 return: -220.8956539118486
# Iteration 401 return: -268.8558881208765
# Iteration 402 return: -199.7776985432122
# Iteration 403 return: -211.59208340661567
# Iteration 404 return: -220.79810533668197
# Iteration 405 return: -222.58677860742873
# Iteration 406 return: -258.7266856499791
# Iteration 407 return: -242.0570204577073
# Iteration 408 return: -237.39141452278815
# Iteration 409 return: -203.87821295658605
# Iteration 410 return: -253.30014530731233
# Iteration 411 return: -225.6717029417508
# Iteration 412 return: -216.39625242798726
# Iteration 413 return: -233.33140391430075
# Iteration 414 return: -229.07822397971913
# Iteration 415 return: -238.6569194020293
# Iteration 416 return: -251.43220534131115
# Iteration 417 return: -245.25936453874058
# Iteration 418 return: -266.4219043302773
# Iteration 419 return: -218.92961582344802
# Iteration 420 return: -218.10028401701734
# Iteration 421 return: -240.32949086816865
# Iteration 422 return: -225.33176308511747
# Iteration 423 return: -254.6308839323917
# Iteration 424 return: -222.1516271929493
# Iteration 425 return: -231.78778622712736
# Iteration 426 return: -242.65948633381845
# Iteration 427 return: -239.48367731203976
# Iteration 428 return: -256.2848192554334
# Iteration 429 return: -247.40763182718283
# Iteration 430 return: -200.96915663548404
# Iteration 431 return: -212.77287384135448
# Iteration 432 return: -214.78365635528564
# Iteration 433 return: -217.71093853433874
# Iteration 434 return: -242.93123456258215
# Iteration 435 return: -235.0952479947916
# Iteration 436 return: -213.24155040868177
# Iteration 437 return: -235.61485330346332
# Iteration 438 return: -215.2109650048726
# Iteration 439 return: -253.45800972166722
# Iteration 440 return: -237.5007740937896
# Iteration 441 return: -212.67247009773496
# Iteration 442 return: -250.5649544021886
# Iteration 443 return: -214.34637414489927
# Iteration 444 return: -219.49085756507057
# Iteration 445 return: -225.67000095417237
# Iteration 446 return: -207.81219527348773
# Iteration 447 return: -237.97834406691925
# Iteration 448 return: -243.0660658715203
# Iteration 449 return: -237.08658734912675
# Iteration 450 return: -242.25737057510705
# Iteration 451 return: -241.59320040224927
# Iteration 452 return: -219.8455915718571
# Iteration 453 return: -225.65942036571045
# Iteration 454 return: -232.39136414034118
# Iteration 455 return: -283.8994253855834
# Iteration 456 return: -194.62499393152012
# Iteration 457 return: -222.2527705303795
# Iteration 458 return: -212.8631281598457
# Iteration 459 return: -229.39863621036332
# Iteration 460 return: -250.16392701129254
# Iteration 461 return: -239.5286011757459
# Iteration 462 return: -246.2869946835881
# Iteration 463 return: -255.66011709851088
# Iteration 464 return: -228.33609749335108
# Iteration 465 return: -238.4425686106314
# Iteration 466 return: -259.21505416386566
# Iteration 467 return: -269.41100466832216
# Iteration 468 return: -224.3425992378773
# Iteration 469 return: -219.82454038202764
# Iteration 470 return: -221.27342697297024
# Iteration 471 return: -232.77957407745046
# Iteration 472 return: -206.21055678355418
# Iteration 473 return: -220.9683276057187
# Iteration 474 return: -236.64945947738428
# Iteration 475 return: -254.51510359645812
# Iteration 476 return: -232.12222673753175
# Iteration 477 return: -226.62452497265127
# Iteration 478 return: -257.7258683299824
# Iteration 479 return: -236.44528262078117
# Iteration 480 return: -213.11095079066988
# Iteration 481 return: -247.36011831735567
# Iteration 482 return: -223.9581863738822
# Iteration 483 return: -235.89239810927782
# Iteration 484 return: -215.11770432966858
# Iteration 485 return: -237.72449039958965
# Iteration 486 return: -223.84949157362377
# Iteration 487 return: -219.09896984794952
# Iteration 488 return: -225.96601859632258
# Iteration 489 return: -240.0828658757872
# Iteration 490 return: -257.88181018698845
# Iteration 491 return: -229.58977576395498
# Iteration 492 return: -217.24062451332483
# Iteration 493 return: -254.8690440316282
# Iteration 494 return: -249.9195555043264
# Iteration 495 return: -220.7375048209593
# Iteration 496 return: -232.4801854687598
# Iteration 497 return: -235.45214721465155
# Iteration 498 return: -238.69833366494848
# Iteration 499 return: -244.49173973610266
#
# ==== Training Run 1 ====
# Iteration 0 return: -1153.6859968996234
# Iteration 1 return: -1220.7092394241195
# Iteration 2 return: -1186.7817678655063
# Iteration 3 return: -1213.955004191438
# Iteration 4 return: -1244.5380459727596
# Iteration 5 return: -1168.7578641702733
# Iteration 6 return: -1109.5659327033225
# Iteration 7 return: -1151.410759947903
# Iteration 8 return: -1129.515636083111
# Iteration 9 return: -1109.674647262326
# Iteration 10 return: -1136.5836769784264
# Iteration 11 return: -1136.1688743930442
# Iteration 12 return: -1132.5127017494897
# Iteration 13 return: -1123.5823234154532
# Iteration 14 return: -1122.7131776888816
# Iteration 15 return: -1091.3071866355526
# Iteration 16 return: -1144.3211657213017
# Iteration 17 return: -1085.3778558918414
# Iteration 18 return: -1123.4943751278054
# Iteration 19 return: -1140.4518210027188
# Iteration 20 return: -1172.610911527307
# Iteration 21 return: -1136.0858251169634
# Iteration 22 return: -1138.511687379616
# Iteration 23 return: -1106.5405536456624
# Iteration 24 return: -1109.4277409644208
# Iteration 25 return: -1126.46751214051
# Iteration 26 return: -1101.2421910970286
# Iteration 27 return: -1135.5182698174162
# Iteration 28 return: -1119.0408270962257
# Iteration 29 return: -1163.990259887301
# Iteration 30 return: -1086.1695961087414
# Iteration 31 return: -1167.604470087594
# Iteration 32 return: -1163.5937848603198
# Iteration 33 return: -1176.1308245553062
# Iteration 34 return: -1117.3495956529243
# Iteration 35 return: -1157.9329332510072
# Iteration 36 return: -1153.538415124941
# Iteration 37 return: -1133.9465261333435
# Iteration 38 return: -1095.3646937387562
# Iteration 39 return: -1137.5880251593765
# Iteration 40 return: -1103.5974009965546
# Iteration 41 return: -1099.037563673025
# Iteration 42 return: -1067.5826467365632
# Iteration 43 return: -1054.1916279255413
# Iteration 44 return: -1011.7851073607042
# Iteration 45 return: -993.9907855642649
# Iteration 46 return: -1003.5044277747907
# Iteration 47 return: -1005.946941897287
# Iteration 48 return: -1031.2756298888382
# Iteration 49 return: -959.0583493141348
# Iteration 50 return: -953.2998453565222
# Iteration 51 return: -1009.7629079657809
# Iteration 52 return: -992.5278571182831
# Iteration 53 return: -998.2370393414702
# Iteration 54 return: -1043.5831186391138
# Iteration 55 return: -1008.9060796894723
# Iteration 56 return: -1078.1929279240035
# Iteration 57 return: -1084.2781744322042
# Iteration 58 return: -1002.8577837900817
# Iteration 59 return: -1033.3869870006292
# Iteration 60 return: -1047.1424381154543
# Iteration 61 return: -1020.7131363311767
# Iteration 62 return: -1020.9363438337575
# Iteration 63 return: -1021.5483850879223
# Iteration 64 return: -1002.1688385601869
# Iteration 65 return: -1006.4294581037418
# Iteration 66 return: -1020.8010065696994
# Iteration 67 return: -956.6799783053311
# Iteration 68 return: -951.2605703093484
# Iteration 69 return: -949.0346363575586
# Iteration 70 return: -920.9082046904113
# Iteration 71 return: -924.4253097190017
# Iteration 72 return: -932.4459744120793
# Iteration 73 return: -907.2469264397289
# Iteration 74 return: -944.2753702264698
# Iteration 75 return: -919.1309368150173
# Iteration 76 return: -944.0733515368196
# Iteration 77 return: -944.0196880554129
# Iteration 78 return: -933.2388876983462
# Iteration 79 return: -934.8481199441152
# Iteration 80 return: -923.3322028832503
# Iteration 81 return: -923.5482046347236
# Iteration 82 return: -874.2282105981923
# Iteration 83 return: -841.428774983068
# Iteration 84 return: -825.3805675204311
# Iteration 85 return: -847.5744000282515
# Iteration 86 return: -858.3641871584858
# Iteration 87 return: -826.2436634585844
# Iteration 88 return: -793.7382114852278
# Iteration 89 return: -783.3907287128512
# Iteration 90 return: -793.0132061243337
# Iteration 91 return: -799.5853451552723
# Iteration 92 return: -788.207851185825
# Iteration 93 return: -769.3678574675479
# Iteration 94 return: -786.7449580043741
# Iteration 95 return: -795.2330402975887
# Iteration 96 return: -825.863192274565
# Iteration 97 return: -789.5506800224978
# Iteration 98 return: -845.6301759909982
# Iteration 99 return: -823.0772580623425
# Iteration 100 return: -805.3628400808457
# Iteration 101 return: -785.0118690404524
# Iteration 102 return: -798.8535780973401
# Iteration 103 return: -754.3649102504054
# Iteration 104 return: -668.8050154381308
# Iteration 105 return: -666.5492659446735
# Iteration 106 return: -605.4596481292051
# Iteration 107 return: -683.537624664839
# Iteration 108 return: -566.341310543239
# Iteration 109 return: -593.8639046092925
# Iteration 110 return: -535.6983298702612
# Iteration 111 return: -550.2647667824135
# Iteration 112 return: -479.60996205554693
# Iteration 113 return: -511.2787136463398
# Iteration 114 return: -545.5763473040543
# Iteration 115 return: -527.0335288983456
# Iteration 116 return: -563.8416565527941
# Iteration 117 return: -622.1587607125895
# Iteration 118 return: -715.556383496026
# Iteration 119 return: -717.5663267261344
# Iteration 120 return: -773.5006134033579
# Iteration 121 return: -833.5490298140868
# Iteration 122 return: -783.4550272258793
# Iteration 123 return: -672.5881349275339
# Iteration 124 return: -713.9202471422808
# Iteration 125 return: -613.0937299966153
# Iteration 126 return: -567.8572252197683
# Iteration 127 return: -522.5874278465235
# Iteration 128 return: -474.1666765893721
# Iteration 129 return: -450.56594968999195
# Iteration 130 return: -473.24132478380983
# Iteration 131 return: -466.4710073101396
# Iteration 132 return: -479.59597299103217
# Iteration 133 return: -462.96685535004633
# Iteration 134 return: -546.0751798347233
# Iteration 135 return: -558.4115259113006
# Iteration 136 return: -448.30718703926277
# Iteration 137 return: -517.1899031600847
# Iteration 138 return: -619.5507595169735
# Iteration 139 return: -531.2406198332333
# Iteration 140 return: -517.2438155745432
# Iteration 141 return: -409.4494341585568
# Iteration 142 return: -514.0629589538917
# Iteration 143 return: -501.690937763054
# Iteration 144 return: -417.9997711721391
# Iteration 145 return: -447.5024343761802
# Iteration 146 return: -378.2451653981251
# Iteration 147 return: -416.5225985089751
# Iteration 148 return: -468.3925493843317
# Iteration 149 return: -488.2251685477118
# Iteration 150 return: -487.4226726116518
# Iteration 151 return: -448.4255110820259
# Iteration 152 return: -449.4769917445003
# Iteration 153 return: -488.53850672887427
# Iteration 154 return: -412.77656779973375
# Iteration 155 return: -386.57832582639776
# Iteration 156 return: -480.2754744103834
# Iteration 157 return: -375.9354580775742
# Iteration 158 return: -546.7282441971315
# Iteration 159 return: -420.9243671333188
# Iteration 160 return: -481.63482479515136
# Iteration 161 return: -436.5124848182269
# Iteration 162 return: -418.3169027475662
# Iteration 163 return: -402.5801828052305
# Iteration 164 return: -416.58620205610396
# Iteration 165 return: -417.3207795258435
# Iteration 166 return: -347.8547044701062
# Iteration 167 return: -430.27930608400686
# Iteration 168 return: -555.2246246812272
# Iteration 169 return: -448.38971172593125
# Iteration 170 return: -449.72483941409786
# Iteration 171 return: -452.7040262660086
# Iteration 172 return: -443.4311678882994
# Iteration 173 return: -397.44369212535526
# Iteration 174 return: -427.48561726956393
# Iteration 175 return: -353.7314778163287
# Iteration 176 return: -461.6975129311966
# Iteration 177 return: -423.70020079875775
# Iteration 178 return: -478.902596255264
# Iteration 179 return: -432.64873165141876
# Iteration 180 return: -529.8696998021824
# Iteration 181 return: -402.70893655928785
# Iteration 182 return: -406.2993180970386
# Iteration 183 return: -353.46255226859216
# Iteration 184 return: -380.88873874158963
# Iteration 185 return: -428.84763468705717
# Iteration 186 return: -382.3328031527681
# Iteration 187 return: -431.15424487825214
# Iteration 188 return: -478.7436838644195
# Iteration 189 return: -425.39768422380587
# Iteration 190 return: -432.92546018314
# Iteration 191 return: -382.3376708189417
# Iteration 192 return: -368.24229537994034
# Iteration 193 return: -383.37479386455
# Iteration 194 return: -407.72553306796215
# Iteration 195 return: -323.5223398588452
# Iteration 196 return: -369.490771696172
# Iteration 197 return: -336.73089899517316
# Iteration 198 return: -351.86413513300084
# Iteration 199 return: -269.17237171854964
# Iteration 200 return: -296.77528237827755
# Iteration 201 return: -330.3474876798651
# Iteration 202 return: -350.68077006969844
# Iteration 203 return: -311.17267415114753
# Iteration 204 return: -293.5739534267962
# Iteration 205 return: -328.5856007182375
# Iteration 206 return: -299.0162688512156
# Iteration 207 return: -323.56017690890434
# Iteration 208 return: -314.7849739092457
# Iteration 209 return: -295.1075006005292
# Iteration 210 return: -317.80707612189894
# Iteration 211 return: -306.1349465273995
# Iteration 212 return: -320.40842681074105
# Iteration 213 return: -367.26930446244825
# Iteration 214 return: -365.54828693542277
# Iteration 215 return: -320.29678024543864
# Iteration 216 return: -292.68193428080065
# Iteration 217 return: -315.87566148338374
# Iteration 218 return: -352.01157126782016
# Iteration 219 return: -285.61263852006346
# Iteration 220 return: -311.9169010836404
# Iteration 221 return: -382.5593010146915
# Iteration 222 return: -358.99489961789516
# Iteration 223 return: -278.09158543641814
# Iteration 224 return: -298.49139590846295
# Iteration 225 return: -327.1311437839252
# Iteration 226 return: -350.8489223230534
# Iteration 227 return: -330.77095271429755
# Iteration 228 return: -343.960329924035
# Iteration 229 return: -339.8496989814801
# Iteration 230 return: -311.90590316661445
# Iteration 231 return: -304.273767047616
# Iteration 232 return: -357.77712249163545
# Iteration 233 return: -381.39052980502413
# Iteration 234 return: -311.0135176755473
# Iteration 235 return: -295.37999725955234
# Iteration 236 return: -336.1400242129919
# Iteration 237 return: -365.29843120128965
# Iteration 238 return: -331.63361237795226
# Iteration 239 return: -311.99777337024625
# Iteration 240 return: -360.3088408115307
# Iteration 241 return: -368.30028547978196
# Iteration 242 return: -361.8777266240242
# Iteration 243 return: -317.3561193616097
# Iteration 244 return: -306.61408551150765
# Iteration 245 return: -343.5877261328704
# Iteration 246 return: -362.7136588206348
# Iteration 247 return: -316.9168451809437
# Iteration 248 return: -307.27733326505626
# Iteration 249 return: -355.3441593467223
# Iteration 250 return: -357.2220936577206
# Iteration 251 return: -334.5600048485545
# Iteration 252 return: -325.9483786410195
# Iteration 253 return: -343.37858210958075
# Iteration 254 return: -348.83016289650567
# Iteration 255 return: -378.9097211702543
# Iteration 256 return: -289.5998024731815
# Iteration 257 return: -318.8229655851569
# Iteration 258 return: -312.0050701821417
# Iteration 259 return: -322.9317541733129
# Iteration 260 return: -340.8440201968034
# Iteration 261 return: -290.23596528138927
# Iteration 262 return: -284.87923684419115
# Iteration 263 return: -329.54551604166744
# Iteration 264 return: -299.45358106956286
# Iteration 265 return: -271.41868969061363
# Iteration 266 return: -284.09191245878844
# Iteration 267 return: -315.67789048721664
# Iteration 268 return: -323.9791122983366
# Iteration 269 return: -292.1016789520127
# Iteration 270 return: -244.74005481463652
# Iteration 271 return: -277.2892269044082
# Iteration 272 return: -299.45392703465313
# Iteration 273 return: -293.8989767748253
# Iteration 274 return: -293.96902698715917
# Iteration 275 return: -266.6453183110691
# Iteration 276 return: -314.3639823446362
# Iteration 277 return: -302.946180654213
# Iteration 278 return: -282.7827243224218
# Iteration 279 return: -296.04827176079743
# Iteration 280 return: -291.9697101971572
# Iteration 281 return: -305.1567705008388
# Iteration 282 return: -270.21779290429765
# Iteration 283 return: -290.46650398571364
# Iteration 284 return: -265.7153735305581
# Iteration 285 return: -320.9676035033625
# Iteration 286 return: -310.18431275562875
# Iteration 287 return: -268.09244949355235
# Iteration 288 return: -291.876994809937
# Iteration 289 return: -263.20128074849526
# Iteration 290 return: -267.03767430612294
# Iteration 291 return: -291.99907348264503
# Iteration 292 return: -303.5573554173918
# Iteration 293 return: -283.26582404974
# Iteration 294 return: -268.70607246704117
# Iteration 295 return: -326.0410259796777
# Iteration 296 return: -285.0394473712908
# Iteration 297 return: -336.0727856589155
# Iteration 298 return: -254.11523484678492
# Iteration 299 return: -286.2803705191453
# Iteration 300 return: -289.4923788607475
# Iteration 301 return: -304.51803486639
# Iteration 302 return: -256.3611362337682
# Iteration 303 return: -257.28383196881134
# Iteration 304 return: -285.1523400746584
# Iteration 305 return: -290.29068558297274
# Iteration 306 return: -310.7955709258744
# Iteration 307 return: -312.7448707648109
# Iteration 308 return: -275.8097502187092
# Iteration 309 return: -303.23263496432577
# Iteration 310 return: -280.8253229349524
# Iteration 311 return: -302.82945441961743
# Iteration 312 return: -286.1708749216194
# Iteration 313 return: -279.1735383170325
# Iteration 314 return: -326.0984493347114
# Iteration 315 return: -307.30895377171345
# Iteration 316 return: -273.7746990762083
# Iteration 317 return: -255.36280149343685
# Iteration 318 return: -299.7272409332878
# Iteration 319 return: -268.92542216237746
# Iteration 320 return: -284.4777565812736
# Iteration 321 return: -233.1528186139647
# Iteration 322 return: -245.62211798661602
# Iteration 323 return: -288.61049170371615
# Iteration 324 return: -264.2422296820203
# Iteration 325 return: -273.10523021229534
# Iteration 326 return: -275.80436122379746
# Iteration 327 return: -232.75326158297065
# Iteration 328 return: -283.32929186198606
# Iteration 329 return: -273.1929257998299
# Iteration 330 return: -258.598338725357
# Iteration 331 return: -286.15061793341636
# Iteration 332 return: -267.218812782084
# Iteration 333 return: -301.5717559880587
# Iteration 334 return: -301.8496674066272
# Iteration 335 return: -288.4493125580342
# Iteration 336 return: -256.2307795726286
# Iteration 337 return: -251.4172751129344
# Iteration 338 return: -261.3466934005211
# Iteration 339 return: -246.71824432501657
# Iteration 340 return: -280.17272179969024
# Iteration 341 return: -263.1144406101186
# Iteration 342 return: -281.0517956793035
# Iteration 343 return: -276.2897761476002
# Iteration 344 return: -245.78382709703703
# Iteration 345 return: -238.18473318880385
# Iteration 346 return: -287.93229307897064
# Iteration 347 return: -282.50055489801406
# Iteration 348 return: -264.1595712943528
# Iteration 349 return: -266.6469011703931
# Iteration 350 return: -256.4979180506742
# Iteration 351 return: -278.32324892676263
# Iteration 352 return: -287.82580255640113
# Iteration 353 return: -269.62039706713153
# Iteration 354 return: -270.3990854192952
# Iteration 355 return: -260.0387023923681
# Iteration 356 return: -226.1394795922482
# Iteration 357 return: -239.69741714923828
# Iteration 358 return: -248.42969663962512
# Iteration 359 return: -336.69624383110664
# Iteration 360 return: -270.41349019010784
# Iteration 361 return: -274.14251222494175
# Iteration 362 return: -261.6833505375237
# Iteration 363 return: -277.7663078459459
# Iteration 364 return: -233.60308370927902
# Iteration 365 return: -252.13438155697241
# Iteration 366 return: -321.9317781311967
# Iteration 367 return: -274.7902475310255
# Iteration 368 return: -276.0645795302117
# Iteration 369 return: -307.9844501083474
# Iteration 370 return: -233.43902067822026
# Iteration 371 return: -287.1651166519403
# Iteration 372 return: -283.12864467131726
# Iteration 373 return: -256.20531546009056
# Iteration 374 return: -251.08853679740656
# Iteration 375 return: -289.13831552958203
# Iteration 376 return: -271.26404717536053
# Iteration 377 return: -272.60978243632115
# Iteration 378 return: -252.0684092118238
# Iteration 379 return: -283.4185079720495
# Iteration 380 return: -271.72518924719736
# Iteration 381 return: -256.7689646996792
# Iteration 382 return: -249.32282233002198
# Iteration 383 return: -261.7886599894127
# Iteration 384 return: -269.17592060423476
# Iteration 385 return: -233.218214199118
# Iteration 386 return: -304.5796802884718
# Iteration 387 return: -303.1698101455696
# Iteration 388 return: -255.01910029815102
# Iteration 389 return: -248.28833480114562
# Iteration 390 return: -281.0587377001901
# Iteration 391 return: -278.08078915633047
# Iteration 392 return: -280.7940592712658
# Iteration 393 return: -271.7332936228107
# Iteration 394 return: -251.4170761407709
# Iteration 395 return: -273.973509745022
# Iteration 396 return: -293.5116039686561
# Iteration 397 return: -271.05352903885205
# Iteration 398 return: -269.22924675333127
# Iteration 399 return: -235.29189589626694
# Iteration 400 return: -224.0939492487547
# Iteration 401 return: -242.23031018861298
# Iteration 402 return: -222.3472812185197
# Iteration 403 return: -241.78564326717762
# Iteration 404 return: -276.9181912328136
# Iteration 405 return: -295.5070790740232
# Iteration 406 return: -274.25277385620757
# Iteration 407 return: -249.60706435908293
# Iteration 408 return: -258.4772953343072
# Iteration 409 return: -242.26414368154153
# Iteration 410 return: -262.6414952305929
# Iteration 411 return: -277.41976738355845
# Iteration 412 return: -274.9764024057984
# Iteration 413 return: -257.46230518556047
# Iteration 414 return: -269.2508557239736
# Iteration 415 return: -276.7286507092201
# Iteration 416 return: -263.02241320418244
# Iteration 417 return: -276.539959922653
# Iteration 418 return: -265.6163694195539
# Iteration 419 return: -267.36789868012414
# Iteration 420 return: -285.39320482686077
# Iteration 421 return: -266.3344796596815
# Iteration 422 return: -270.5895446202404
# Iteration 423 return: -277.4867589438402
# Iteration 424 return: -225.25370901004788
# Iteration 425 return: -258.94840614675013
# Iteration 426 return: -262.68087254226407
# Iteration 427 return: -284.5600141146266
# Iteration 428 return: -271.202829826616
# Iteration 429 return: -272.9793534819196
# Iteration 430 return: -234.64792723177675
# Iteration 431 return: -264.1742180023307
# Iteration 432 return: -281.2357233049539
# Iteration 433 return: -262.53633616160045
# Iteration 434 return: -307.6994383027601
# Iteration 435 return: -270.32580128875117
# Iteration 436 return: -288.31882156039046
# Iteration 437 return: -255.3813643178923
# Iteration 438 return: -272.1455217897374
# Iteration 439 return: -281.78556505032526
# Iteration 440 return: -287.0958597897752
# Iteration 441 return: -275.21554825700696
# Iteration 442 return: -262.65287667575444
# Iteration 443 return: -240.88841251895468
# Iteration 444 return: -241.0004751347833
# Iteration 445 return: -248.96269723819123
# Iteration 446 return: -263.5745998246604
# Iteration 447 return: -254.28449255739474
# Iteration 448 return: -253.57106379358584
# Iteration 449 return: -237.17312815916318
# Iteration 450 return: -230.9884558492853
# Iteration 451 return: -259.34205658956
# Iteration 452 return: -232.3103778384152
# Iteration 453 return: -278.8960786521364
# Iteration 454 return: -273.4691089615665
# Iteration 455 return: -242.46143977906132
# Iteration 456 return: -280.44602998596287
# Iteration 457 return: -238.56822341450217
# Iteration 458 return: -239.3204927692555
# Iteration 459 return: -236.9989516607023
# Iteration 460 return: -271.21012861679634
# Iteration 461 return: -244.60451543464072
# Iteration 462 return: -209.17057459463607
# Iteration 463 return: -287.3285433636764
# Iteration 464 return: -249.42518498931028
# Iteration 465 return: -271.1015369412058
# Iteration 466 return: -250.62509780010433
# Iteration 467 return: -234.81100641659654
# Iteration 468 return: -244.61141375056545
# Iteration 469 return: -269.65198992675494
# Iteration 470 return: -248.18442979851136
# Iteration 471 return: -275.9903300906489
# Iteration 472 return: -248.0042789663161
# Iteration 473 return: -243.2728620520349
# Iteration 474 return: -240.63342181875973
# Iteration 475 return: -303.6220103439792
# Iteration 476 return: -225.1610796098055
# Iteration 477 return: -277.6023265161741
# Iteration 478 return: -248.7999740470802
# Iteration 479 return: -292.2820026768176
# Iteration 480 return: -232.14237517490892
# Iteration 481 return: -246.1413494836631
# Iteration 482 return: -275.00329035863865
# Iteration 483 return: -269.39368332654396
# Iteration 484 return: -239.56488915502803
# Iteration 485 return: -245.9349929874208
# Iteration 486 return: -275.69332047785247
# Iteration 487 return: -236.75648312737468
# Iteration 488 return: -292.310898264644
# Iteration 489 return: -235.7710107042358
# Iteration 490 return: -264.2734124844434
# Iteration 491 return: -225.14447665510167
# Iteration 492 return: -243.14656909106915
# Iteration 493 return: -205.11584167592963
# Iteration 494 return: -243.51894912907377
# Iteration 495 return: -261.5967163819924
# Iteration 496 return: -275.98721930804476
# Iteration 497 return: -239.48592910741942
# Iteration 498 return: -243.78556344870705
# Iteration 499 return: -266.14591397050503
#
# ==== Training Run 2 ====
# Iteration 0 return: -1252.3020511585598
# Iteration 1 return: -1164.6447176698255
# Iteration 2 return: -1131.1626251083953
# Iteration 3 return: -1125.6901816568773
# Iteration 4 return: -1185.1278502481027
# Iteration 5 return: -1112.8316345185872
# Iteration 6 return: -1199.944664440987
# Iteration 7 return: -1172.913531483366
# Iteration 8 return: -1177.454774044926
# Iteration 9 return: -1186.4049309592942
# Iteration 10 return: -1144.13102349064
# Iteration 11 return: -1165.710251942873
# Iteration 12 return: -1082.5450863686174
# Iteration 13 return: -1141.7231667017502
# Iteration 14 return: -1113.3258678249176
# Iteration 15 return: -1111.3609835035788
# Iteration 16 return: -1132.9734850292373
# Iteration 17 return: -1131.529287835669
# Iteration 18 return: -1110.7300081149924
# Iteration 19 return: -1149.6881131579526
# Iteration 20 return: -1151.554597377119
# Iteration 21 return: -1101.8367200199204
# Iteration 22 return: -1085.0502341901588
# Iteration 23 return: -1117.1756845630969
# Iteration 24 return: -1135.3541700677497
# Iteration 25 return: -1174.6022660900528
# Iteration 26 return: -1145.0875997929027
# Iteration 27 return: -1160.138935662095
# Iteration 28 return: -1180.194166664144
# Iteration 29 return: -1205.2930323372098
# Iteration 30 return: -1211.4508851335818
# Iteration 31 return: -1248.640081199982
# Iteration 32 return: -1197.1411949426183
# Iteration 33 return: -1169.474576682585
# Iteration 34 return: -1172.8077511823549
# Iteration 35 return: -1179.9542672046512
# Iteration 36 return: -1142.8262084213209
# Iteration 37 return: -1174.691038352071
# Iteration 38 return: -1095.5100994905006
# Iteration 39 return: -1098.808212419721
# Iteration 40 return: -1082.4611441977552
# Iteration 41 return: -1101.4759669652021
# Iteration 42 return: -1079.3424102479282
# Iteration 43 return: -1076.772890132914
# Iteration 44 return: -1074.066196316493
# Iteration 45 return: -1055.327606387632
# Iteration 46 return: -1076.643947675839
# Iteration 47 return: -1072.5776714590254
# Iteration 48 return: -1031.276098597444
# Iteration 49 return: -1055.2699491616827
# Iteration 50 return: -1034.6358317711747
# Iteration 51 return: -1077.0705002949123
# Iteration 52 return: -1088.0854019312872
# Iteration 53 return: -1085.1980860763183
# Iteration 54 return: -1079.7969360373495
# Iteration 55 return: -1092.5904510366574
# Iteration 56 return: -1115.980411832972
# Iteration 57 return: -1100.7676216511552
# Iteration 58 return: -1084.586936260361
# Iteration 59 return: -1068.422092529082
# Iteration 60 return: -1068.690901509278
# Iteration 61 return: -1089.55136324731
# Iteration 62 return: -1066.8356186577212
# Iteration 63 return: -1118.731399272038
# Iteration 64 return: -1108.0639666230697
# Iteration 65 return: -1131.4502313702744
# Iteration 66 return: -1059.838671397573
# Iteration 67 return: -1075.0709167337627
# Iteration 68 return: -1074.1112429381658
# Iteration 69 return: -1056.7138789802354
# Iteration 70 return: -1032.3765181772446
# Iteration 71 return: -1017.4655017907902
# Iteration 72 return: -1014.0184512818605
# Iteration 73 return: -957.4940999826509
# Iteration 74 return: -929.7735925397277
# Iteration 75 return: -964.2068567717091
# Iteration 76 return: -929.0649372501625
# Iteration 77 return: -944.4097222539402
# Iteration 78 return: -928.6236900388969
# Iteration 79 return: -932.7464022781141
# Iteration 80 return: -932.0569218771097
# Iteration 81 return: -922.4812569533048
# Iteration 82 return: -883.6976729273272
# Iteration 83 return: -899.413883379718
# Iteration 84 return: -924.7580395337815
# Iteration 85 return: -930.6589633957856
# Iteration 86 return: -918.2925064943421
# Iteration 87 return: -875.9359179126417
# Iteration 88 return: -871.1350270710401
# Iteration 89 return: -873.3416241015967
# Iteration 90 return: -883.6545547463078
# Iteration 91 return: -795.4569870972866
# Iteration 92 return: -816.8485100596911
# Iteration 93 return: -806.4018718017793
# Iteration 94 return: -815.2500620325624
# Iteration 95 return: -772.1171098479241
# Iteration 96 return: -736.9757038372314
# Iteration 97 return: -744.002171296329
# Iteration 98 return: -780.1572239670775
# Iteration 99 return: -745.3618515034199
# Iteration 100 return: -695.7603177047614
# Iteration 101 return: -652.6468824397773
# Iteration 102 return: -670.4394928613117
# Iteration 103 return: -675.7763936691995
# Iteration 104 return: -669.5190430834028
# Iteration 105 return: -673.4009856931116
# Iteration 106 return: -664.854188021046
# Iteration 107 return: -659.5926268684631
# Iteration 108 return: -630.4280740386904
# Iteration 109 return: -625.966495078151
# Iteration 110 return: -594.4194626618893
# Iteration 111 return: -645.8296131643278
# Iteration 112 return: -587.8464285094328
# Iteration 113 return: -570.4214832555355
# Iteration 114 return: -561.0322782629105
# Iteration 115 return: -496.0128500417976
# Iteration 116 return: -524.176433116359
# Iteration 117 return: -542.4150877546278
# Iteration 118 return: -456.2024298710386
# Iteration 119 return: -431.2760589754409
# Iteration 120 return: -357.7389482207499
# Iteration 121 return: -384.83478873577474
# Iteration 122 return: -343.91165075489795
# Iteration 123 return: -395.9205778441216
# Iteration 124 return: -400.2912969253681
# Iteration 125 return: -442.919449027414
# Iteration 126 return: -430.37624277514163
# Iteration 127 return: -433.33003188039356
# Iteration 128 return: -423.3252181822635
# Iteration 129 return: -385.91072920820193
# Iteration 130 return: -535.9695597562853
# Iteration 131 return: -566.5288807182237
# Iteration 132 return: -491.0125134850377
# Iteration 133 return: -527.8560858136186
# Iteration 134 return: -469.26973448739716
# Iteration 135 return: -485.4785860384104
# Iteration 136 return: -431.7934862831625
# Iteration 137 return: -441.51293881741867
# Iteration 138 return: -495.01899038655023
# Iteration 139 return: -434.76600481186273
# Iteration 140 return: -381.8151352072058
# Iteration 141 return: -415.491434290508
# Iteration 142 return: -423.0154438187573
# Iteration 143 return: -409.0418508231128
# Iteration 144 return: -423.53317648002024
# Iteration 145 return: -358.3671455445019
# Iteration 146 return: -324.70815392759323
# Iteration 147 return: -326.87787064006864
# Iteration 148 return: -333.9091593377507
# Iteration 149 return: -359.45069715471726
# Iteration 150 return: -314.7743020988081
# Iteration 151 return: -278.67977145132664
# Iteration 152 return: -305.79891672761323
# Iteration 153 return: -306.1578190397226
# Iteration 154 return: -281.525245451757
# Iteration 155 return: -269.27076065937337
# Iteration 156 return: -269.86709249291704
# Iteration 157 return: -285.3921210197832
# Iteration 158 return: -280.9543229552894
# Iteration 159 return: -319.1372548388629
# Iteration 160 return: -261.3722266035041
# Iteration 161 return: -295.60162450806695
# Iteration 162 return: -289.93264221031694
# Iteration 163 return: -230.53112533736052
# Iteration 164 return: -251.58214186248753
# Iteration 165 return: -292.0343692330309
# Iteration 166 return: -288.63007472962215
# Iteration 167 return: -277.6513608221194
# Iteration 168 return: -255.39191003806695
# Iteration 169 return: -317.48224412297867
# Iteration 170 return: -281.40989512136605
# Iteration 171 return: -304.3339189332858
# Iteration 172 return: -276.401872307253
# Iteration 173 return: -295.95044149722173
# Iteration 174 return: -256.0210470625797
# Iteration 175 return: -297.0358895230797
# Iteration 176 return: -308.6293003278962
# Iteration 177 return: -297.3629748084754
# Iteration 178 return: -294.5736553784186
# Iteration 179 return: -256.85307634169567
# Iteration 180 return: -264.1401293112492
# Iteration 181 return: -278.14656045855224
# Iteration 182 return: -309.3961303927784
# Iteration 183 return: -300.06946842143816
# Iteration 184 return: -296.5889032694351
# Iteration 185 return: -269.9167921160448
# Iteration 186 return: -260.72375457662577
# Iteration 187 return: -319.86905905023866
# Iteration 188 return: -274.85448994455857
# Iteration 189 return: -287.2479032353497
# Iteration 190 return: -269.8924463485592
# Iteration 191 return: -262.2844707982136
# Iteration 192 return: -271.3425999176291
# Iteration 193 return: -302.31261865805476
# Iteration 194 return: -322.54571206036417
# Iteration 195 return: -285.3880468931382
# Iteration 196 return: -288.06965069689693
# Iteration 197 return: -314.4995011881828
# Iteration 198 return: -319.1715119546663
# Iteration 199 return: -271.4658243250578
# Iteration 200 return: -275.23522787866244
# Iteration 201 return: -292.0299597188871
# Iteration 202 return: -305.535545461037
# Iteration 203 return: -286.79686615281173
# Iteration 204 return: -320.93072894551045
# Iteration 205 return: -286.19964841527116
# Iteration 206 return: -288.96394773936106
# Iteration 207 return: -297.5767981766215
# Iteration 208 return: -261.2951092750334
# Iteration 209 return: -297.23120372700816
# Iteration 210 return: -307.63597443172705
# Iteration 211 return: -320.53847434375757
# Iteration 212 return: -261.38683940773103
# Iteration 213 return: -323.73319987086893
# Iteration 214 return: -280.6794072134525
# Iteration 215 return: -249.1715225065733
# Iteration 216 return: -347.54050399291054
# Iteration 217 return: -293.4687265858763
# Iteration 218 return: -289.0148762372839
# Iteration 219 return: -343.4778103720519
# Iteration 220 return: -274.5559480792132
# Iteration 221 return: -278.6745418738461
# Iteration 222 return: -311.533692323242
# Iteration 223 return: -335.3458588317251
# Iteration 224 return: -301.8064973914214
# Iteration 225 return: -269.47282789458717
# Iteration 226 return: -306.0280001781841
# Iteration 227 return: -290.8897384254131
# Iteration 228 return: -291.18509932369835
# Iteration 229 return: -323.63413081970504
# Iteration 230 return: -323.47045318062516
# Iteration 231 return: -283.37645647084634
# Iteration 232 return: -285.3534121934332
# Iteration 233 return: -219.49173583025438
# Iteration 234 return: -286.5745046937756
# Iteration 235 return: -261.15570930265983
# Iteration 236 return: -249.07830178365785
# Iteration 237 return: -251.22039280517225
# Iteration 238 return: -289.1007634257762
# Iteration 239 return: -289.7754314028841
# Iteration 240 return: -256.2410273418028
# Iteration 241 return: -310.134431097022
# Iteration 242 return: -249.90803772070106
# Iteration 243 return: -262.80844320809894
# Iteration 244 return: -253.43137726171938
# Iteration 245 return: -286.59377641604203
# Iteration 246 return: -253.35736135025823
# Iteration 247 return: -287.5595393335751
# Iteration 248 return: -268.53421315417467
# Iteration 249 return: -229.23209536043552
# Iteration 250 return: -269.6866560581004
# Iteration 251 return: -243.9059959537212
# Iteration 252 return: -257.4351033601724
# Iteration 253 return: -297.35113630118207
# Iteration 254 return: -244.9575037796713
# Iteration 255 return: -272.07814230419365
# Iteration 256 return: -278.9850838766887
# Iteration 257 return: -272.24971103757036
# Iteration 258 return: -291.43843538551755
# Iteration 259 return: -233.76757954291864
# Iteration 260 return: -282.24236386211345
# Iteration 261 return: -265.5794031265476
# Iteration 262 return: -253.1947812321777
# Iteration 263 return: -226.89289311709328
# Iteration 264 return: -272.94560124331724
# Iteration 265 return: -237.78105912331696
# Iteration 266 return: -247.42740505706897
# Iteration 267 return: -298.30651176752593
# Iteration 268 return: -254.17565586721824
# Iteration 269 return: -265.0684471825432
# Iteration 270 return: -261.46872735861365
# Iteration 271 return: -283.1581586754923
# Iteration 272 return: -250.09621678861058
# Iteration 273 return: -255.6302107204099
# Iteration 274 return: -274.89727461455294
# Iteration 275 return: -273.6952866591179
# Iteration 276 return: -263.58989993067854
# Iteration 277 return: -241.08202184293594
# Iteration 278 return: -207.8315118833864
# Iteration 279 return: -264.59652244970937
# Iteration 280 return: -221.20748113829052
# Iteration 281 return: -257.8488678336791
# Iteration 282 return: -236.09167358508626
# Iteration 283 return: -255.70211090326163
# Iteration 284 return: -281.1772972775954
# Iteration 285 return: -265.5620076239546
# Iteration 286 return: -199.56767625603814
# Iteration 287 return: -215.6843988667389
# Iteration 288 return: -244.84356445559067
# Iteration 289 return: -252.9104199880503
# Iteration 290 return: -251.82676330640004
# Iteration 291 return: -254.12803213796875
# Iteration 292 return: -264.6522318646062
# Iteration 293 return: -249.54509367489192
# Iteration 294 return: -273.33919586956114
# Iteration 295 return: -240.09004826542082
# Iteration 296 return: -242.6080160391825
# Iteration 297 return: -283.82207224541594
# Iteration 298 return: -256.82644002523494
# Iteration 299 return: -286.74467079841247
# Iteration 300 return: -276.10629478063356
# Iteration 301 return: -269.3448974537961
# Iteration 302 return: -238.08084150358656
# Iteration 303 return: -249.60092851879347
# Iteration 304 return: -249.79590682487125
# Iteration 305 return: -255.14992193615123
# Iteration 306 return: -227.0272826506834
# Iteration 307 return: -214.587027511856
# Iteration 308 return: -261.66114143889774
# Iteration 309 return: -246.3850555517406
# Iteration 310 return: -245.50734676073057
# Iteration 311 return: -232.02653270490177
# Iteration 312 return: -250.3137569666812
# Iteration 313 return: -266.16503770490124
# Iteration 314 return: -248.1643791364472
# Iteration 315 return: -261.3225806422594
# Iteration 316 return: -265.0060781245148
# Iteration 317 return: -224.19225707007806
# Iteration 318 return: -260.66210357904754
# Iteration 319 return: -246.29607692295875
# Iteration 320 return: -236.60892352798817
# Iteration 321 return: -270.3437562509541
# Iteration 322 return: -236.8541953109488
# Iteration 323 return: -250.13951914620668
# Iteration 324 return: -287.2329528473238
# Iteration 325 return: -268.3135066470103
# Iteration 326 return: -237.15974283216352
# Iteration 327 return: -219.37831986864913
# Iteration 328 return: -219.83110463086442
# Iteration 329 return: -229.55590592641428
# Iteration 330 return: -242.6423436447668
# Iteration 331 return: -261.2871448652465
# Iteration 332 return: -274.53753099594564
# Iteration 333 return: -257.72087938493854
# Iteration 334 return: -277.40111904746277
# Iteration 335 return: -257.4695840930121
# Iteration 336 return: -229.8831284698943
# Iteration 337 return: -247.3786001992578
# Iteration 338 return: -204.76882396726495
# Iteration 339 return: -260.1338126213779
# Iteration 340 return: -244.0303665941373
# Iteration 341 return: -228.66087709579048
# Iteration 342 return: -274.09658797951613
# Iteration 343 return: -250.84636531952464
# Iteration 344 return: -226.13972755938903
# Iteration 345 return: -223.0347030781844
# Iteration 346 return: -253.02199435944752
# Iteration 347 return: -236.51215710260797
# Iteration 348 return: -240.00078137964235
# Iteration 349 return: -210.9896203523725
# Iteration 350 return: -240.05752692136195
# Iteration 351 return: -238.18324648053138
# Iteration 352 return: -227.8197762508591
# Iteration 353 return: -250.01675292230695
# Iteration 354 return: -256.7186422180369
# Iteration 355 return: -228.05694591303913
# Iteration 356 return: -272.1457008530528
# Iteration 357 return: -228.4725502717493
# Iteration 358 return: -225.8238305131182
# Iteration 359 return: -242.06829975879276
# Iteration 360 return: -226.31904661135408
# Iteration 361 return: -269.2724363741093
# Iteration 362 return: -250.60741686564066
# Iteration 363 return: -270.1386616017637
# Iteration 364 return: -244.7515967408902
# Iteration 365 return: -271.998669360181
# Iteration 366 return: -238.8856603530455
# Iteration 367 return: -238.6275116962321
# Iteration 368 return: -274.606546002067
# Iteration 369 return: -254.37932316778412
# Iteration 370 return: -258.04588500127244
# Iteration 371 return: -239.62108792720878
# Iteration 372 return: -260.33956955865796
# Iteration 373 return: -287.7929830692359
# Iteration 374 return: -281.5036968539901
# Iteration 375 return: -239.12954264031558
# Iteration 376 return: -241.11886725565995
# Iteration 377 return: -251.02376791101258
# Iteration 378 return: -272.1584421634193
# Iteration 379 return: -246.2861324146093
# Iteration 380 return: -227.40775848406543
# Iteration 381 return: -287.1534496452058
# Iteration 382 return: -228.86283164069783
# Iteration 383 return: -256.19019314038803
# Iteration 384 return: -262.0697986692445
# Iteration 385 return: -266.62181549712625
# Iteration 386 return: -247.26097129289653
# Iteration 387 return: -279.8733384071464
# Iteration 388 return: -266.07355756670165
# Iteration 389 return: -231.1678424422084
# Iteration 390 return: -266.336817826581
# Iteration 391 return: -242.18024379924833
# Iteration 392 return: -263.95703333085504
# Iteration 393 return: -243.07256222436132
# Iteration 394 return: -268.76525586477794
# Iteration 395 return: -283.7993771900774
# Iteration 396 return: -282.299138362419
# Iteration 397 return: -237.97311795906097
# Iteration 398 return: -272.97011538354565
# Iteration 399 return: -237.5383493945556
# Iteration 400 return: -242.06794758095978
# Iteration 401 return: -287.858675557912
# Iteration 402 return: -279.6574142383022
# Iteration 403 return: -247.7807906568489
# Iteration 404 return: -248.40872867573398
# Iteration 405 return: -293.96646064344355
# Iteration 406 return: -263.58701377849826
# Iteration 407 return: -260.6351159787256
# Iteration 408 return: -286.9975172086334
# Iteration 409 return: -263.6608040632043
# Iteration 410 return: -267.50565584937846
# Iteration 411 return: -231.40245910929855
# Iteration 412 return: -287.83544977065475
# Iteration 413 return: -242.90753041260498
# Iteration 414 return: -274.34584896272236
# Iteration 415 return: -238.6905174764772
# Iteration 416 return: -260.75540448499004
# Iteration 417 return: -281.367249051861
# Iteration 418 return: -284.0402856847295
# Iteration 419 return: -252.92357711655586
# Iteration 420 return: -265.15081018823884
# Iteration 421 return: -219.33650676022245
# Iteration 422 return: -279.6083084951865
# Iteration 423 return: -289.6775687372255
# Iteration 424 return: -266.95663980785633
# Iteration 425 return: -291.1539762906937
# Iteration 426 return: -251.18994776068163
# Iteration 427 return: -288.6930514739814
# Iteration 428 return: -294.7950255368212
# Iteration 429 return: -279.01927128065097
# Iteration 430 return: -272.4434774253233
# Iteration 431 return: -293.0408152840406
# Iteration 432 return: -274.34144311906846
# Iteration 433 return: -242.19787721735202
# Iteration 434 return: -279.88368968917615
# Iteration 435 return: -239.1592027330739
# Iteration 436 return: -263.3132301133017
# Iteration 437 return: -256.94506142551285
# Iteration 438 return: -249.33587911873735
# Iteration 439 return: -259.3581606386611
# Iteration 440 return: -260.35947882648964
# Iteration 441 return: -269.56751778727335
# Iteration 442 return: -253.86275041253447
# Iteration 443 return: -240.74871746855032
# Iteration 444 return: -252.2406885892313
# Iteration 445 return: -261.3268778606756
# Iteration 446 return: -278.6685780497456
# Iteration 447 return: -227.32657345745207
# Iteration 448 return: -254.81447916825263
# Iteration 449 return: -245.10986319380646
# Iteration 450 return: -248.44247349397415
# Iteration 451 return: -208.31584253746695
# Iteration 452 return: -233.28986200200535
# Iteration 453 return: -244.55955307616813
# Iteration 454 return: -278.29461489747627
# Iteration 455 return: -238.5992113937975
# Iteration 456 return: -244.19726400741865
# Iteration 457 return: -256.62764489255517
# Iteration 458 return: -251.74123722615735
# Iteration 459 return: -308.3280881456842
# Iteration 460 return: -234.42608694586252
# Iteration 461 return: -219.518874205495
# Iteration 462 return: -257.1338264708183
# Iteration 463 return: -258.9288705253076
# Iteration 464 return: -251.78132545769958
# Iteration 465 return: -249.5939930079486
# Iteration 466 return: -229.75500172076184
# Iteration 467 return: -248.96511820536756
# Iteration 468 return: -255.98570350987632
# Iteration 469 return: -258.91190490595915
# Iteration 470 return: -282.3376504361754
# Iteration 471 return: -223.17151951841797
# Iteration 472 return: -223.191154277329
# Iteration 473 return: -283.6526010778648
# Iteration 474 return: -269.76242572316784
# Iteration 475 return: -244.8902621142881
# Iteration 476 return: -275.50560876656345
# Iteration 477 return: -252.99697586067055
# Iteration 478 return: -210.3534058855521
# Iteration 479 return: -277.7274810406898
# Iteration 480 return: -261.9309792493032
# Iteration 481 return: -279.26409652236305
# Iteration 482 return: -256.96442255295324
# Iteration 483 return: -234.216318843763
# Iteration 484 return: -229.53236546018957
# Iteration 485 return: -264.1166852471926
# Iteration 486 return: -236.87803166727633
# Iteration 487 return: -209.31540760648124
# Iteration 488 return: -266.5219192031382
# Iteration 489 return: -212.05150641941648
# Iteration 490 return: -260.2169077289084
# Iteration 491 return: -249.14951667530545
# Iteration 492 return: -224.73631511439206
# Iteration 493 return: -267.9361472712088
# Iteration 494 return: -240.63631344745235
# Iteration 495 return: -270.2692613075398
# Iteration 496 return: -276.5976228611757
# Iteration 497 return: -225.5454579732116
# Iteration 498 return: -225.59080798612175
# Iteration 499 return: -218.86853205480293

# %%
# collect saved results
import numpy as np
r1 = np.genfromtxt("InvertedPendulum_results.csv", delimiter=",")
all_results = [r1]
labels = ["REINFORCE"]

##############################################################
# Plot your Policy Gradient results below
##############################################################
import matplotlib.pyplot as plt
arrays = [np.array(x) for x in r1]
mean = [np.mean(k) for k in zip(*arrays)]
maximum = [np.max(k) for k in zip(*arrays)]
minimum = [np.min(k) for k in zip(*arrays)]
plt.plot(mean, label = "Average Reward")
plt.plot(maximum, label = "Upper Bound")
plt.plot(minimum, label = "Lower Bound")

plt.xlabel('Epochs')
# Set the y axis label of the current axis.
plt.ylabel('Average Cumulative Reward')
# Set a title of the current axes.
plt.title('Average Reward vs Epochs ')
# show a legend on the plot
plt.legend()

# %%
arrays = [np.array(x) for x in r1]
[np.max(k) for k in zip(*arrays)]
# Out:
# [-1153.6859968996234,
#  -1140.2230289396518,
#  -1109.7723370533056,
#  -1125.6901816568773,
#  -1156.0942307918099,
#  -1112.8316345185872,
#  -1109.5659327033225,
#  -1151.410759947903,
#  -1129.515636083111,
#  -1109.674647262326,
#  -1136.5836769784264,
#  -1136.1688743930442,
#  -1082.5450863686174,
#  -1123.5823234154532,
#  -1113.3258678249176,
#  -1091.3071866355526,
#  -1132.9734850292373,
#  -1085.3778558918414,
#  -1110.7300081149924,
#  -1133.9703269950517,
#  -1151.554597377119,
#  -1101.8367200199204,
#  -1085.0502341901588,
#  -1106.5405536456624,
#  -1109.4277409644208,
#  -1126.46751214051,
#  -1101.2421910970286,
#  -1135.5182698174162,
#  -1119.0408270962257,
#  -1119.972023323498,
#  -1086.1695961087414,
#  -1145.7721763771865,
#  -1078.9699954006371,
#  -1081.4111000064295,
#  -1060.2482994511415,
#  -1088.4030227634814,
#  -1098.0829689908687,
#  -1072.0769460101853,
#  -1095.3646937387562,
#  -1044.0399848488687,
#  -1037.4532423910498,
#  -1044.192935516429,
#  -1048.626550968384,
#  -1054.1916279255413,
#  -1011.7851073607042,
#  -993.9907855642649,
#  -1003.5044277747907,
#  -1005.946941897287,
#  -1031.2756298888382,
#  -959.0583493141348,
#  -953.2998453565222,
#  -1009.7629079657809,
#  -992.5278571182831,
#  -998.2370393414702,
#  -1043.5831186391138,
#  -1008.9060796894723,
#  -1070.6020153963939,
#  -1084.2781744322042,
#  -1002.8577837900817,
#  -1033.3869870006292,
#  -1047.1424381154543,
#  -1020.7131363311767,
#  -1020.9363438337575,
#  -1021.5483850879223,
#  -1002.1688385601869,
#  -1006.4294581037418,
#  -1020.8010065696994,
#  -956.6799783053311,
#  -951.2605703093484,
#  -949.0346363575586,
#  -920.9082046904113,
#  -924.4253097190017,
#  -932.4459744120793,
#  -907.2469264397289,
#  -929.7735925397277,
#  -919.1309368150173,
#  -929.0649372501625,
#  -944.0196880554129,
#  -928.6236900388969,
#  -932.7464022781141,
#  -923.3322028832503,
#  -922.4812569533048,
#  -874.2282105981923,
#  -841.428774983068,
#  -825.3805675204311,
#  -847.5744000282515,
#  -858.3641871584858,
#  -826.2436634585844,
#  -793.7382114852278,
#  -783.3907287128512,
#  -793.0132061243337,
#  -795.4569870972866,
#  -788.207851185825,
#  -769.3678574675479,
#  -786.7449580043741,
#  -772.1171098479241,
#  -736.9757038372314,
#  -744.002171296329,
#  -780.1572239670775,
#  -745.3618515034199,
#  -695.7603177047614,
#  -652.6468824397773,
#  -670.4394928613117,
#  -675.7763936691995,
#  -668.8050154381308,
#  -666.5492659446735,
#  -605.4596481292051,
#  -659.5926268684631,
#  -566.341310543239,
#  -593.8639046092925,
#  -535.6983298702612,
#  -550.2647667824135,
#  -479.60996205554693,
#  -511.2787136463398,
#  -545.5763473040543,
#  -496.0128500417976,
#  -524.176433116359,
#  -542.4150877546278,
#  -456.2024298710386,
#  -431.2760589754409,
#  -357.7389482207499,
#  -384.83478873577474,
#  -343.91165075489795,
#  -395.9205778441216,
#  -400.2912969253681,
#  -442.919449027414,
#  -430.37624277514163,
#  -433.33003188039356,
#  -423.3252181822635,
#  -385.91072920820193,
#  -401.9562539188248,
#  -408.41887305255466,
#  -367.33848785513635,
#  -313.51788493780333,
#  -285.96443797783536,
#  -310.7990859082799,
#  -278.30881025251233,
#  -272.92834321612145,
#  -262.8564624036215,
#  -251.95462268697258,
#  -248.13581649597947,
#  -243.47545801020814,
#  -250.70113774752278,
#  -247.98234339746315,
#  -260.29325221012976,
#  -256.7820436367327,
#  -259.70057924571626,
#  -272.25675835157847,
#  -288.25601151465,
#  -225.27315040056428,
#  -236.03207133622868,
#  -265.69006097642364,
#  -289.37816418009936,
#  -231.08208470349956,
#  -220.6375917855625,
#  -244.142248903501,
#  -243.35508796493434,
#  -236.95358863728373,
#  -227.71753984397063,
#  -232.83813426989906,
#  -242.60417820133583,
#  -283.3601692348215,
#  -229.91233720942537,
#  -230.53112533736052,
#  -251.58214186248753,
#  -284.31711838593867,
#  -265.9177457578163,
#  -210.35811960606233,
#  -220.40941443797726,
#  -235.62949563634416,
#  -246.64135287356257,
#  -256.35584882709054,
#  -230.6198359376927,
#  -233.60831541606336,
#  -229.66432326399226,
#  -266.8825761253504,
#  -248.05669926325058,
#  -237.05405439748864,
#  -244.5252900854335,
#  -229.19345327842913,
#  -233.39827463945315,
#  -257.280290901273,
#  -274.8363617447607,
#  -264.83563296483277,
#  -221.44432778535892,
#  -259.65446046388126,
#  -199.6671642976955,
#  -275.3233809204461,
#  -268.3548787291843,
#  -280.6161321711377,
#  -269.8924463485592,
#  -234.74706196986642,
#  -246.41137483723375,
#  -233.2281666761237,
#  -216.90277718696262,
#  -274.9383784174829,
#  -257.21501732074944,
#  -262.9766390462042,
#  -254.82692263567392,
#  -253.33908945923991,
#  -256.97541554668317,
#  -234.82526867013632,
#  -226.37076307638372,
#  -264.4791654865833,
#  -269.40698351784175,
#  -209.29476021223252,
#  -255.83390959263247,
#  -254.20742352660082,
#  -223.64780052528965,
#  -271.82660613195316,
#  -245.76449441606383,
#  -245.96929444666563,
#  -261.38683940773103,
#  -234.3729962908029,
#  -262.9612759970059,
#  -249.1715225065733,
#  -225.72845830853058,
#  -255.82456993484539,
#  -245.11363260692588,
#  -208.5560137183908,
#  -274.5559480792132,
#  -245.84065937146582,
#  -243.75331977886108,
#  -265.3511545870328,
#  -245.09836487743857,
#  -222.36465059433837,
#  -265.4540318873286,
#  -290.8897384254131,
#  -278.6594869452741,
#  -266.46189577911485,
#  -235.0075286557506,
#  -244.1157401614515,
#  -263.9417703992488,
#  -219.49173583025438,
#  -243.1862116693766,
#  -215.44304054096844,
#  -249.07830178365785,
#  -251.22039280517225,
#  -284.54973109374527,
#  -225.9840352485866,
#  -233.53422261239484,
#  -216.57422374102873,
#  -241.34778125368436,
#  -248.36314928485245,
#  -236.45823997245472,
#  -286.59377641604203,
#  -241.90723740715393,
#  -230.8671908812597,
#  -254.00347021916096,
#  -229.23209536043552,
#  -265.1910449262668,
#  -240.03232022758039,
#  -253.44908974202932,
#  -229.60037665587473,
#  -234.830881321184,
#  -253.91878396497268,
#  -266.27222265837406,
#  -232.40803849715246,
#  -259.94959427258897,
#  -233.76757954291864,
#  -266.36401109189427,
#  -235.96627590756486,
#  -250.17697741352225,
#  -226.89289311709328,
#  -239.64542416499904,
#  -237.78105912331696,
#  -246.76116044854933,
#  -247.89035823695133,
#  -252.23588908455307,
#  -251.3561860406475,
#  -212.2728713603051,
#  -204.34136289724492,
#  -240.03055166548893,
#  -245.26859771723724,
#  -261.1470382143499,
#  -217.94371252350416,
#  -231.71846067813564,
#  -241.08202184293594,
#  -207.8315118833864,
#  -224.09634274345018,
#  -221.20748113829052,
#  -257.8488678336791,
#  -230.28703015948375,
#  -255.70211090326163,
#  -259.2802924962928,
#  -246.07660566900012,
#  -199.56767625603814,
#  -215.6843988667389,
#  -244.84356445559067,
#  -221.6049523374884,
#  -251.82676330640004,
#  -254.12803213796875,
#  -254.94140168096632,
#  -249.54509367489192,
#  -241.73974956202767,
#  -240.09004826542082,
#  -242.6080160391825,
#  -283.82207224541594,
#  -254.11523484678492,
#  -237.0387428828869,
#  -265.2545220263124,
#  -231.85173251840428,
#  -238.08084150358656,
#  -249.60092851879347,
#  -218.88683830865125,
#  -226.03831655162057,
#  -192.0160275902607,
#  -214.587027511856,
#  -261.66114143889774,
#  -246.3850555517406,
#  -205.49036874557765,
#  -232.02653270490177,
#  -240.45145941633885,
#  -233.9939806997376,
#  -248.1643791364472,
#  -209.12187491718421,
#  -242.24141810619074,
#  -224.19225707007806,
#  -241.22333633643402,
#  -206.67489254204185,
#  -204.16958096063885,
#  -233.1528186139647,
#  -235.92236066966748,
#  -235.2447687956519,
#  -264.2422296820203,
#  -268.3135066470103,
#  -223.3244964861034,
#  -219.37831986864913,
#  -219.83110463086442,
#  -225.76879721744152,
#  -218.90001630834115,
#  -202.16712764951842,
#  -237.07120842252493,
#  -257.72087938493854,
#  -256.1241449651562,
#  -257.4695840930121,
#  -229.8831284698943,
#  -222.7561947208801,
#  -204.76882396726495,
#  -203.98931720340522,
#  -244.0303665941373,
#  -208.79082757056636,
#  -253.14896082633814,
#  -224.01417765557844,
#  -224.84238599660466,
#  -223.0347030781844,
#  -228.78934711076917,
#  -225.96729223595204,
#  -240.00078137964235,
#  -209.11919696405303,
#  -240.05752692136195,
#  -224.15913454350667,
#  -227.8197762508591,
#  -211.63115055366399,
#  -209.77576563840998,
#  -213.48228886876615,
#  -226.1394795922482,
#  -228.4725502717493,
#  -203.8159171389629,
#  -242.06829975879276,
#  -225.77054348623923,
#  -229.05890347530624,
#  -250.60741686564066,
#  -234.61743415250447,
#  -233.60308370927902,
#  -252.13438155697241,
#  -238.8856603530455,
#  -237.69749240092915,
#  -220.6066240888767,
#  -216.85964729791385,
#  -233.43902067822026,
#  -238.42602189955107,
#  -232.03022212724866,
#  -229.07505527477713,
#  -224.59636799322794,
#  -239.12954264031558,
#  -213.81316443948646,
#  -237.98377642860817,
#  -239.7082057788709,
#  -235.49195556129072,
#  -227.40775848406543,
#  -214.93135905603197,
#  -201.76007133329009,
#  -217.69978741006014,
#  -231.66398052542064,
#  -213.22996662775336,
#  -230.57504357285927,
#  -231.57736385594976,
#  -232.69962228598627,
#  -213.01776308306543,
#  -218.85311024243947,
#  -242.18024379924833,
#  -255.10760157158762,
#  -201.4539088587719,
#  -207.61504302558382,
#  -184.20382463818277,
#  -262.4183931739859,
#  -237.97311795906097,
#  -207.96965275588082,
#  -209.52748868723847,
#  -220.8956539118486,
#  -242.23031018861298,
#  -199.7776985432122,
#  -211.59208340661567,
#  -220.79810533668197,
#  -222.58677860742873,
#  -258.7266856499791,
#  -242.0570204577073,
#  -237.39141452278815,
#  -203.87821295658605,
#  -253.30014530731233,
#  -225.6717029417508,
#  -216.39625242798726,
#  -233.33140391430075,
#  -229.07822397971913,
#  -238.6569194020293,
#  -251.43220534131115,
#  -245.25936453874058,
#  -265.6163694195539,
#  -218.92961582344802,
#  -218.10028401701734,
#  -219.33650676022245,
#  -225.33176308511747,
#  -254.6308839323917,
#  -222.1516271929493,
#  -231.78778622712736,
#  -242.65948633381845,
#  -239.48367731203976,
#  -256.2848192554334,
#  -247.40763182718283,
#  -200.96915663548404,
#  -212.77287384135448,
#  -214.78365635528564,
#  -217.71093853433874,
#  -242.93123456258215,
#  -235.0952479947916,
#  -213.24155040868177,
#  -235.61485330346332,
#  -215.2109650048726,
#  -253.45800972166722,
#  -237.5007740937896,
#  -212.67247009773496,
#  -250.5649544021886,
#  -214.34637414489927,
#  -219.49085756507057,
#  -225.67000095417237,
#  -207.81219527348773,
#  -227.32657345745207,
#  -243.0660658715203,
#  -237.08658734912675,
#  -230.9884558492853,
#  -208.31584253746695,
#  -219.8455915718571,
#  -225.65942036571045,
#  -232.39136414034118,
#  -238.5992113937975,
#  -194.62499393152012,
#  -222.2527705303795,
#  -212.8631281598457,
#  -229.39863621036332,
#  -234.42608694586252,
#  -219.518874205495,
#  -209.17057459463607,
#  -255.66011709851088,
#  -228.33609749335108,
#  -238.4425686106314,
#  -229.75500172076184,
#  -234.81100641659654,
#  -224.3425992378773,
#  -219.82454038202764,
#  -221.27342697297024,
#  -223.17151951841797,
#  -206.21055678355418,
#  -220.9683276057187,
#  -236.64945947738428,
#  -244.8902621142881,
#  -225.1610796098055,
#  -226.62452497265127,
#  -210.3534058855521,
#  -236.44528262078117,
#  -213.11095079066988,
#  -246.1413494836631,
#  -223.9581863738822,
#  -234.216318843763,
#  -215.11770432966858,
#  -237.72449039958965,
#  -223.84949157362377,
#  -209.31540760648124,
#  -225.96601859632258,
#  -212.05150641941648,
#  -257.88181018698845,
#  -225.14447665510167,
#  -217.24062451332483,
#  -205.11584167592963,
#  -240.63631344745235,
#  -220.7375048209593,
#  -232.4801854687598,
#  -225.5454579732116,
#  -225.59080798612175,
#  -218.86853205480293]

# %%
# Out:
# 500

# %%
import gym
env = gym.make("Pendulum-v0")
alg = REINFORCE(env, stochastic=True)
res = alg.train(learning_rate=0.005, gamma=0.95, num_iterations=500, steps_per_iteration=15000)
# Out:
# Iteration 0 return: -1176.672904675665
# Iteration 1 return: -1216.070022443294
# Iteration 2 return: -1202.7490132704238
# Iteration 3 return: -1192.1133482048435
# Iteration 4 return: -1150.1559171369174
# Iteration 5 return: -1175.6979074835808
# Iteration 6 return: -1147.6036206579704
# Iteration 7 return: -1170.4140696778304
# Iteration 8 return: -1180.566206840739
# Iteration 9 return: -1173.9213256384246
# Iteration 10 return: -1162.0856930122695
# Iteration 11 return: -1123.389557506116
# Iteration 12 return: -1081.3361173125356
# Iteration 13 return: -1083.3513626295887
# Iteration 14 return: -1126.9422290097953
# Iteration 15 return: -1134.3817024097903
# Iteration 16 return: -1090.9773416251999
# Iteration 17 return: -1092.1848565194198
# Iteration 18 return: -1097.9710116537397
# Iteration 19 return: -1104.3135218242153
# Iteration 20 return: -1092.4861924437698
# Iteration 21 return: -1119.253131153487
# Iteration 22 return: -1125.8656160365729
# Iteration 23 return: -1149.3907671681234
# Iteration 24 return: -1158.024512619429
# Iteration 25 return: -1191.1546824589263
# Iteration 26 return: -1209.2003104963574
# Iteration 27 return: -1127.4266977838422
# Iteration 28 return: -1105.332903324471
# Iteration 29 return: -1159.1053099334783
# Iteration 30 return: -1134.1979501112867
# Iteration 31 return: -1123.1358576822747
# Iteration 32 return: -1097.6929919516629
# Iteration 33 return: -1077.5685688401138
# Iteration 34 return: -1128.4771914831797
# Iteration 35 return: -1097.1751910599073
# Iteration 36 return: -1117.7052405154145
# Iteration 37 return: -1066.3282564427705
# Iteration 38 return: -1093.186408592444
# Iteration 39 return: -1120.0476025449918
# Iteration 40 return: -1097.6841285640157
# Iteration 41 return: -1091.7039208984809
# Iteration 42 return: -1061.5917349065212
# Iteration 43 return: -1051.079910956417
# Iteration 44 return: -1083.12740735591
# Iteration 45 return: -1075.7726294106913
# Iteration 46 return: -1060.304780695461
# Iteration 47 return: -1034.0188047988402
# Iteration 48 return: -1081.410818901061
# Iteration 49 return: -1056.944384352496
# Iteration 50 return: -997.513867427834
# Iteration 51 return: -1024.971458240327
# Iteration 52 return: -1061.8659735800652
# Iteration 53 return: -1036.621025050804
# Iteration 54 return: -1009.0347707512951
# Iteration 55 return: -998.6762772426196
# Iteration 56 return: -1034.0410727148535
# Iteration 57 return: -1015.7193781924714
# Iteration 58 return: -1000.3450700691874
# Iteration 59 return: -981.1700698698183
# Iteration 60 return: -1009.5305230436475
# Iteration 61 return: -1003.4577767267451
# Iteration 62 return: -1020.9993485291799
# Iteration 63 return: -1025.087427036283
# Iteration 64 return: -991.1252220528154
# Iteration 65 return: -955.5378675293418
# Iteration 66 return: -948.7195849435404
# Iteration 67 return: -983.1741642009762
# Iteration 68 return: -979.3355228657539
# Iteration 69 return: -982.8843996973732
# Iteration 70 return: -965.9876097237272
# Iteration 71 return: -937.3895189739442
# Iteration 72 return: -981.323917626588
# Iteration 73 return: -955.4250061897825
# Iteration 74 return: -932.6301806326264
# Iteration 75 return: -1024.2850125419573
# Iteration 76 return: -1036.6699924402885
# Iteration 77 return: -1100.0060218872643
# Iteration 78 return: -1105.83129342773
# Iteration 79 return: -1140.4209119115212
# Iteration 80 return: -1168.2562398796404
# Iteration 81 return: -1154.3544977273762
# Iteration 82 return: -1175.7546038694059
# Iteration 83 return: -1166.8080222535057
# Iteration 84 return: -1186.2252401605
# Iteration 85 return: -1139.0974189552292
# Iteration 86 return: -1127.726609800666
# Iteration 87 return: -1089.4209560161348
# Iteration 88 return: -983.9096199201754
# Iteration 89 return: -957.9952321708521
# Iteration 90 return: -947.1536326706371
# Iteration 91 return: -926.1884394101799
# Iteration 92 return: -925.935092498855
# Iteration 93 return: -910.3721043055925
# Iteration 94 return: -900.7287558186008
# Iteration 95 return: -851.6218251087736
# Iteration 96 return: -842.9327862177737
# Iteration 97 return: -881.7067592719088
# Iteration 98 return: -879.3141341468009
# Iteration 99 return: -882.4639687323004
# Iteration 100 return: -850.777045417733
# Iteration 101 return: -898.5374178421016
# Iteration 102 return: -903.03722541374
# Iteration 103 return: -855.2770312777984
# Iteration 104 return: -867.6277752529492
# Iteration 105 return: -830.4743897939233
# Iteration 106 return: -810.9257000065377
# Iteration 107 return: -844.630136039225
# Iteration 108 return: -821.97668138861
# Iteration 109 return: -811.8998949654106
# Iteration 110 return: -869.5976756964469
# Iteration 111 return: -841.3170700717252
# Iteration 112 return: -789.5031180721164
# Iteration 113 return: -820.3791609510065
# Iteration 114 return: -798.4993985001278
# Iteration 115 return: -756.0831484489455
# Iteration 116 return: -794.527476348773
# Iteration 117 return: -796.217025225102
# Iteration 118 return: -776.4021395265344
# Iteration 119 return: -739.7528397030259
# Iteration 120 return: -776.1962403197073
# Iteration 121 return: -717.360567859499
# Iteration 122 return: -688.6291327871169
# Iteration 123 return: -659.4652345451381
# Iteration 124 return: -654.1659676108451
# Iteration 125 return: -562.1908151814928
# Iteration 126 return: -579.4030751607706
# Iteration 127 return: -574.1915962292958
# Iteration 128 return: -541.2145765863759
# Iteration 129 return: -623.4454657838978
# Iteration 130 return: -592.2778068581507
# Iteration 131 return: -569.3827229325373
# Iteration 132 return: -524.1756311039337
# Iteration 133 return: -486.713732777429
# Iteration 134 return: -388.8628346982559
# Iteration 135 return: -418.3312329332683
# Iteration 136 return: -505.2433105888461
# Iteration 137 return: -441.9345372614089
# Iteration 138 return: -436.4909704605294
# Iteration 139 return: -381.6283760897203
# Iteration 140 return: -465.97604438928613
# Iteration 141 return: -450.6431820459258
# Iteration 142 return: -401.55079007697503
# Iteration 143 return: -440.02719366106254
# Iteration 144 return: -365.6842369309717
# Iteration 145 return: -323.4510733819684
# Iteration 146 return: -361.97155296406595
# Iteration 147 return: -390.1795101174233
# Iteration 148 return: -311.2281852232467
# Iteration 149 return: -331.0291508184206
# Iteration 150 return: -310.4713303561503
# Iteration 151 return: -331.79921694112454
# Iteration 152 return: -351.6733120365272
# Iteration 153 return: -294.88212775686634
# Iteration 154 return: -280.44029202558573
# Iteration 155 return: -297.5353216378806
# Iteration 156 return: -281.51715359078605
# Iteration 157 return: -303.2426083492989
# Iteration 158 return: -310.89442752157066
# Iteration 159 return: -312.70407473456646
# Iteration 160 return: -277.841807132671
# Iteration 161 return: -285.37276941863473
# Iteration 162 return: -259.63651310086874
# Iteration 163 return: -286.7764831814117
# Iteration 164 return: -242.3403327415939
# Iteration 165 return: -318.29583410849824
# Iteration 166 return: -322.7359500872408
# Iteration 167 return: -290.3741410522515
# Iteration 168 return: -306.04412363493196
# Iteration 169 return: -288.84555998074273
# Iteration 170 return: -264.5471984959996
# Iteration 171 return: -263.83987059846015
# Iteration 172 return: -284.33606420504685
# Iteration 173 return: -311.4224110757152
# Iteration 174 return: -289.8323211311276
# Iteration 175 return: -330.64941009882097
# Iteration 176 return: -308.61223418516784
# Iteration 177 return: -282.67345583853825
# Iteration 178 return: -312.73137979396887
# Iteration 179 return: -317.1589722405993
# Iteration 180 return: -296.3652396233098
# Iteration 181 return: -297.14876315696495
# Iteration 182 return: -291.5700354363309
# Iteration 183 return: -317.09873700405706
# Iteration 184 return: -294.9655661941866
# Iteration 185 return: -317.4316813525599
# Iteration 186 return: -291.686396729915
# Iteration 187 return: -338.06037066646036
# Iteration 188 return: -345.7117613085537
# Iteration 189 return: -354.77482326416566
# Iteration 190 return: -303.30814343619977
# Iteration 191 return: -275.8677024051267
# Iteration 192 return: -322.1194956567146
# Iteration 193 return: -306.06593649859155
# Iteration 194 return: -295.4456060917721
# Iteration 195 return: -316.970318953652
# Iteration 196 return: -299.35654285634934
# Iteration 197 return: -312.00595950124364
# Iteration 198 return: -275.9754055075648
# Iteration 199 return: -322.38914946311553
# Iteration 200 return: -280.7417754131759
# Iteration 201 return: -303.83947420473237
# Iteration 202 return: -289.63777164116703
# Iteration 203 return: -247.6417345573952
# Iteration 204 return: -272.524448039401
# Iteration 205 return: -294.18981498674714
# Iteration 206 return: -282.8498741671
# Iteration 207 return: -316.0783947183751
# Iteration 208 return: -294.6612975531109
# Iteration 209 return: -284.34711704108963
# Iteration 210 return: -260.73246681788856
# Iteration 211 return: -244.9213242970637
# Iteration 212 return: -259.704750873135
# Iteration 213 return: -330.9469633249419
# Iteration 214 return: -279.6631845114073
# Iteration 215 return: -251.44114336943875
# Iteration 216 return: -280.7762685203804
# Iteration 217 return: -251.27046506076664
# Iteration 218 return: -265.5040556994265
# Iteration 219 return: -290.89602422310776
# Iteration 220 return: -279.3924148030481
# Iteration 221 return: -273.0065919118637
# Iteration 222 return: -277.75630557678323
# Iteration 223 return: -285.9353746998324
# Iteration 224 return: -282.4383741024068
# Iteration 225 return: -289.1597516139794
# Iteration 226 return: -282.7478081265537
# Iteration 227 return: -252.7053283665175
# Iteration 228 return: -295.0312296848339
# Iteration 229 return: -275.0831826815323
# Iteration 230 return: -222.79854376668274
# Iteration 231 return: -284.5589265199087
# Iteration 232 return: -266.06611426251163
# Iteration 233 return: -245.86980365758222
# Iteration 234 return: -307.2057068418943
# Iteration 235 return: -272.75686188903944
# Iteration 236 return: -300.574777851818
# Iteration 237 return: -266.4283132788583
# Iteration 238 return: -281.71559273930325
# Iteration 239 return: -272.0723867538265
# Iteration 240 return: -266.6247860757805
# Iteration 241 return: -281.25017321461365
# Iteration 242 return: -289.8790346904288
# Iteration 243 return: -256.5835418852472
# Iteration 244 return: -279.9935203815322
# Iteration 245 return: -246.5588252249043
# Iteration 246 return: -291.76233413828527
# Iteration 247 return: -259.3477238124268
# Iteration 248 return: -271.8852438624326
# Iteration 249 return: -255.15805516434102
# Iteration 250 return: -274.95282895443563
# Iteration 251 return: -264.5986756825152
# Iteration 252 return: -258.12578791242805
# Iteration 253 return: -244.18242172664785
# Iteration 254 return: -299.8816389174427
# Iteration 255 return: -258.2966378892324
# Iteration 256 return: -270.29845905559193
# Iteration 257 return: -247.33900438131727
# Iteration 258 return: -239.070703902552
# Iteration 259 return: -251.89141718460382
# Iteration 260 return: -266.01792442377393
# Iteration 261 return: -287.32818157753934
# Iteration 262 return: -250.93178488592483
# Iteration 263 return: -267.33846617803516
# Iteration 264 return: -281.7442755788545
# Iteration 265 return: -252.7713335318678
# Iteration 266 return: -268.9314021457763
# Iteration 267 return: -297.13853907978597
# Iteration 268 return: -259.4419493770693
# Iteration 269 return: -264.41566606384924
# Iteration 270 return: -246.20278239480666
# Iteration 271 return: -233.8880073917108
# Iteration 272 return: -269.41222229223797
# Iteration 273 return: -250.38730065688878
# Iteration 274 return: -258.6209028477016
# Iteration 275 return: -277.0331129810343
# Iteration 276 return: -251.9894923719954
# Iteration 277 return: -265.1249262640798
# Iteration 278 return: -266.6822318712876
# Iteration 279 return: -247.61682591137495
# Iteration 280 return: -267.80770279127324
# Iteration 281 return: -290.12023547334985
# Iteration 282 return: -285.9130253762309
# Iteration 283 return: -253.9409938678484
# Iteration 284 return: -260.5697711002781
# Iteration 285 return: -311.69808288278824
# Iteration 286 return: -276.5245315808238
# Iteration 287 return: -287.7610438752205
# Iteration 288 return: -255.61531143873265
# Iteration 289 return: -314.6989939583193
# Iteration 290 return: -240.66421947636488
# Iteration 291 return: -285.95956630918835
# Iteration 292 return: -269.92094241620674
# Iteration 293 return: -228.25547843635388
# Iteration 294 return: -267.3465467059959
# Iteration 295 return: -306.55905125590647
# Iteration 296 return: -228.84625852727214
# Iteration 297 return: -231.87794664979825
# Iteration 298 return: -260.3073082133615
# Iteration 299 return: -252.18506911725805
# Iteration 300 return: -261.4954062356634
# Iteration 301 return: -236.31819411324753
# Iteration 302 return: -259.14243427644885
# Iteration 303 return: -298.0317120815419
# Iteration 304 return: -269.25266214640794
# Iteration 305 return: -221.68865365307468
# Iteration 306 return: -276.8135620961781
# Iteration 307 return: -250.70751226783614
# Iteration 308 return: -290.62586580943037
# Iteration 309 return: -308.4904481290806
# Iteration 310 return: -315.5677502822497
# Iteration 311 return: -264.62866809691894
# Iteration 312 return: -218.98637311476642
# Iteration 313 return: -267.74234919802075
# Iteration 314 return: -264.25275687309716
# Iteration 315 return: -281.14885640096986
# Iteration 316 return: -336.09880993208566
# Iteration 317 return: -321.12083769170977
# Iteration 318 return: -293.8543322586994
# Iteration 319 return: -267.68936556913343
# Iteration 320 return: -277.5936036954523
# Iteration 321 return: -325.32169152017764
# Iteration 322 return: -261.8841896702989
# Iteration 323 return: -300.63817341597354
# Iteration 324 return: -321.1880166696596
# Iteration 325 return: -279.5902547311842
# Iteration 326 return: -270.1563398100563
# Iteration 327 return: -319.0949322424106
# Iteration 328 return: -245.38465734591742
# Iteration 329 return: -309.4286845922696
# Iteration 330 return: -284.543904587836
# Iteration 331 return: -276.8872075910156
# Iteration 332 return: -263.90431192049573
# Iteration 333 return: -278.2593119111521
# Iteration 334 return: -240.09487875159175
# Iteration 335 return: -258.27794558438654
# Iteration 336 return: -286.8909777159493
# Iteration 337 return: -258.51888915671424
# Iteration 338 return: -290.6556645030566
# Iteration 339 return: -304.73711956412166
# Iteration 340 return: -265.19147858941744
# Iteration 341 return: -250.67865855400134
# Iteration 342 return: -302.14941054222805
# Iteration 343 return: -267.0739076824847
# Iteration 344 return: -285.42695786304364
# Iteration 345 return: -281.1566587383116
# Iteration 346 return: -247.8324566825781
# Iteration 347 return: -266.706207211694
# Iteration 348 return: -272.3701119255745
# Iteration 349 return: -279.56201065048907
# Iteration 350 return: -248.34291894161856
# Iteration 351 return: -216.71616955539915
# Iteration 352 return: -282.70461093941134
# Iteration 353 return: -257.7621648316674
# Iteration 354 return: -246.6741996208719
# Iteration 355 return: -246.19918078740614
# Iteration 356 return: -217.77051059154675
# Iteration 357 return: -305.7080049070419
# Iteration 358 return: -267.9994386254158
# Iteration 359 return: -269.07119088563894
# Iteration 360 return: -238.02497711159347
# Iteration 361 return: -257.09687939889915
# Iteration 362 return: -240.8318225911342
# Iteration 363 return: -253.11903180212772
# Iteration 364 return: -263.3599519153304
# Iteration 365 return: -246.82723883132903
# Iteration 366 return: -244.31335476572426
# Iteration 367 return: -273.15147869481626
# Iteration 368 return: -244.31417850950393
# Iteration 369 return: -237.15953878333502
# Iteration 370 return: -251.71394077572577
# Iteration 371 return: -225.8619882350234
# Iteration 372 return: -305.69741491573114
# Iteration 373 return: -262.8121273530471
# Iteration 374 return: -249.2999763293606
# Iteration 375 return: -237.94786001661734
# Iteration 376 return: -263.09913013931373
# Iteration 377 return: -205.26120710770996
# Iteration 378 return: -240.14910376359768
# Iteration 379 return: -227.38510092835884
# Iteration 380 return: -238.6719058498258
# Iteration 381 return: -231.7708395038263
# Iteration 382 return: -257.21569743373624
# Iteration 383 return: -233.2356044537999
# Iteration 384 return: -262.20687028377847
# Iteration 385 return: -252.93994376932315
# Iteration 386 return: -252.39909529049444
# Iteration 387 return: -286.21154237323316
# Iteration 388 return: -254.91878279954156
# Iteration 389 return: -250.44953048102082
# Iteration 390 return: -247.66092468927653
# Iteration 391 return: -224.51070032021826
# Iteration 392 return: -254.71229851903325
# Iteration 393 return: -225.20899824649877
# Iteration 394 return: -241.07325356866292
# Iteration 395 return: -293.60666453911284
# Iteration 396 return: -277.33525951205365
# Iteration 397 return: -235.00957334197727
# Iteration 398 return: -247.01207749258276
# Iteration 399 return: -234.49120061489404
# Iteration 400 return: -230.42907326605612
# Iteration 401 return: -255.80010022247856
# Iteration 402 return: -256.034285565452
# Iteration 403 return: -241.8543080634423
# Iteration 404 return: -263.77052237971935
# Iteration 405 return: -243.6500137097767
# Iteration 406 return: -256.8704163692485
# Iteration 407 return: -269.0633947495273
# Iteration 408 return: -259.7147233295584
# Iteration 409 return: -258.73079836556815
# Iteration 410 return: -269.2721389989191
# Iteration 411 return: -239.4586613636296
# Iteration 412 return: -298.10623085138593
# Iteration 413 return: -250.75805831219924
# Iteration 414 return: -239.79803569955018
# Iteration 415 return: -266.42095710009096
# Iteration 416 return: -241.38116710023382
# Iteration 417 return: -268.7931202029759
# Iteration 418 return: -272.2879849508338
# Iteration 419 return: -253.91952693945552
# Iteration 420 return: -300.4976608304382
# Iteration 421 return: -250.3444531086159
# Iteration 422 return: -226.61415200585955
# Iteration 423 return: -271.72649283052556
# Iteration 424 return: -243.81723058133997
# Iteration 425 return: -258.58146426362526
# Iteration 426 return: -281.30465745374715
# Iteration 427 return: -292.59693746423096
# Iteration 428 return: -274.07309948576847
# Iteration 429 return: -247.74834551416637
# Iteration 430 return: -281.3941149775908
# Iteration 431 return: -262.8676746750861
# Iteration 432 return: -252.6992310064102
# Iteration 433 return: -267.61056102590044
# Iteration 434 return: -323.45666105296385
# Iteration 435 return: -262.27053665040467
# Iteration 436 return: -269.42559607333135
# Iteration 437 return: -291.6074942830687
# Iteration 438 return: -292.2785530413174
# Iteration 439 return: -288.3391140692915
# Iteration 440 return: -261.1093486598369
# Iteration 441 return: -250.55152209657706
# Iteration 442 return: -227.26790407153672
# Iteration 443 return: -217.49053432455094
# Iteration 444 return: -269.3944022952641
# Iteration 445 return: -281.56148341285154
# Iteration 446 return: -294.38330280302887
# Iteration 447 return: -251.98425355021797
# Iteration 448 return: -275.0232108219678
# Iteration 449 return: -301.08036419268456
# Iteration 450 return: -263.34977600671226
# Iteration 451 return: -269.18305236317605
# Iteration 452 return: -286.24287935235225
# Iteration 453 return: -224.74535778513012
# Iteration 454 return: -269.6628263682842
# Iteration 455 return: -231.40389040619843
# Iteration 456 return: -255.81425116212756
# Iteration 457 return: -292.06429435642787
# Iteration 458 return: -288.1993565431951
# Iteration 459 return: -290.96569988823785
# Iteration 460 return: -264.752435807909
# Iteration 461 return: -237.89323619875344
# Iteration 462 return: -265.5090142193514
# Iteration 463 return: -243.88527001317183
# Iteration 464 return: -266.80913608097813
# Iteration 465 return: -302.67187545577053
# Iteration 466 return: -253.90407470412248
# Iteration 467 return: -256.80648676571224
# Iteration 468 return: -262.51757118880596
# Iteration 469 return: -255.1699242391248
# Iteration 470 return: -243.00477957918213
# Iteration 471 return: -218.59845035762118
# Iteration 472 return: -269.3417869067945
# Iteration 473 return: -262.9447749252916
# Iteration 474 return: -272.30161124067894
# Iteration 475 return: -235.81011911020124
# Iteration 476 return: -274.77579940199973
# Iteration 477 return: -266.2817134705488
# Iteration 478 return: -222.11062642870897
# Iteration 479 return: -278.6402053980121
# Iteration 480 return: -239.21898848351154
# Iteration 481 return: -218.74200634086912
# Iteration 482 return: -241.38665004862094
# Iteration 483 return: -260.5064551296643
# Iteration 484 return: -264.8592292839823
# Iteration 485 return: -235.5612957312844
# Iteration 486 return: -259.23273214391634
# Iteration 487 return: -218.06411632955198
# Iteration 488 return: -228.21509977734473
# Iteration 489 return: -227.63861036902827
# Iteration 490 return: -270.17128939810385
# Iteration 491 return: -247.26906295118766
# Iteration 492 return: -276.1129116507514
# Iteration 493 return: -222.08236281925483
# Iteration 494 return: -227.08302824387656
# Iteration 495 return: -225.30238585004233
# Iteration 496 return: -233.63430928386012
# Iteration 497 return: -273.4908629945865
# Iteration 498 return: -250.89197472494678
# Iteration 499 return: -264.833150307059

# %%
for i_episode in range(1):
    observation = env.reset()
    for t in range(10000):
        env.render()
        print(observation)
        action = alg.compute_action(observation.reshape(1,3))
        #action = env.action_space.sample()
        print(action)
        observation, reward, done, info = env.step(action)
        if done:
            print("Episode finished after {} timesteps".format(t+1))
            break
env.close()
# Out:
# [-0.99988858  0.01492726 -0.42502619]
# [[-0.55599374]]
# [[-0.9992085 ]
#  [ 0.03977885]
#  [-0.4972298 ]]
# [[1.2491729]]
# [[-0.99855363]
#  [ 0.05376431]
#  [-0.2800196 ]]
# [[0.21866187]]
# [[-0.99794406]
#  [ 0.06409103]
#  [-0.20689699]]
# [[-1.1028786]]
# [[-0.99677384]
#  [ 0.0802615 ]
#  [-0.32426056]]
# [[4.8273478]]
# [[-0.9969164 ]
#  [ 0.07847045]
#  [ 0.03593552]]
# [[1.5523735]]
# [[-0.99806815]
#  [ 0.06212895]
#  [ 0.32764432]]
# [[1.7207189]]
# [[-0.99953336]
#  [ 0.03054683]
#  [ 0.6323488 ]]
# [[-0.91345334]]
# [[-0.9999892 ]
#  [ 0.00463952]
#  [ 0.51824063]]
# [[0.9453262]]
# [[-0.99959284]
#  [-0.02853253]
#  [ 0.66351914]]
# [[1.6007528]]
# [[-0.99736226]
#  [-0.07258425]
#  [ 0.8822326 ]]
# [[3.4095542]]
# [[-0.99168617]
#  [-0.12868014]
#  [ 1.1277944 ]]
# [[6.3498497]]
# [[-0.9809308 ]
#  [-0.19435735]
#  [ 1.3312842 ]]
# [[6.08978]]
# [[-0.9638034 ]
#  [-0.26661384]
#  [ 1.4855163 ]]
# [[5.782338]]
# [[-0.93966186]
#  [-0.3421046 ]
#  [ 1.5855559 ]]
# [[7.777542]]
# [[-0.9087136 ]
#  [-0.41742024]
#  [ 1.6289772 ]]
# [[2.5693097]]
# [[-0.8720602 ]
#  [-0.48939866]
#  [ 1.615912  ]]
# [[6.9937153]]
# [[-0.83158374]
#  [-0.5553994 ]
#  [ 1.548863  ]]
# [[7.804121]]
# [[-0.7897108 ]
#  [-0.61347926]
#  [ 1.4323136 ]]
# [[7.420901]]
# [[-0.7491165]
#  [-0.6624383]
#  [ 1.2722039]]
# [[6.17907]]
# [[-0.7124326]
#  [-0.7017405]
#  [ 1.0753751]]
# [[7.90769]]
# [[-0.6820083]
#  [-0.7313444]
#  [ 0.8490698]]
# [[2.192926]]
# [[-0.6597433 ]
#  [-0.75149107]
#  [ 0.6005614 ]]
# [[6.991745]]
# [[-0.64698976]
#  [-0.7624987 ]
#  [ 0.3369429 ]]
# [[3.4186387]]
# [[-0.6445056 ]
#  [-0.76459956]
#  [ 0.06506899]]
# [[1.8369331]]
# [[-0.65336317]
#  [-0.7570446 ]
#  [-0.2328409 ]]
# [[-1.5368569]]
# [[-0.69150907]
#  [-0.72236776]
#  [-1.0311527 ]]
# [[4.659301]]
# [[-0.73605394]
#  [-0.67692286]
#  [-1.2729285 ]]
# [[0.8652188]]
# [[-0.7893591 ]
#  [-0.61393183]
#  [-1.6508378 ]]
# [[-0.66718566]]
# [[-0.85228205]
#  [-0.5230825 ]
#  [-2.2113647 ]]
# [[-2.2853432]]
# [[-0.91899204]
#  [-0.39427605]
#  [-2.9036767 ]]
# [[1.3499252]]
# [[-0.9675534 ]
#  [-0.25266662]
#  [-2.9968948 ]]
# [[-1.3917472]]
# [[-0.99633193]
#  [-0.08557269]
#  [-3.395157  ]]
# [[-3.8654363]]
# [[-0.99477303]
#  [ 0.10211106]
#  [-3.759337  ]]
# [[-3.2439647]]
# [[-0.9549138]
#  [ 0.2968832]
#  [-3.9827535]]
# [[-0.8562679]]
# [[-0.8795629]
#  [ 0.4757826]
#  [-3.8885312]]
# [[-2.0014184]]
# [[-0.7728742 ]
#  [ 0.63455933]
#  [-3.8316941 ]]
# [[-4.976412]]
# [[-0.644653 ]
#  [ 0.7644753]
#  [-3.6557746]]
# [[-5.966604]]
# [[-0.50678265]
#  [ 0.8620739 ]
#  [-3.3824182 ]]
# [[-1.1340432]]
# [[-0.37662473]
#  [ 0.9263659 ]
#  [-2.9059691 ]]
# [[-4.424652]]
# [[-0.257651 ]
#  [ 0.966238 ]
#  [-2.5111947]]
# [[-8.416325]]
# [[-0.1556294]
#  [ 0.9878155]
#  [-2.0865161]]
# [[-6.055565]]
# [[-0.07391433]
#  [ 0.9972646 ]
#  [-1.6456546 ]]
# [[-4.52423]]
# [[-0.01409608]
#  [ 0.99990064]
#  [-1.1977061 ]]
# [[-1.8095801]]
# [[ 0.02186263]
#  [ 0.999761  ]
#  [-0.71921766]]
# [[-3.3377318]]
# [[ 0.03532683]
#  [ 0.9993758 ]
#  [-0.2693969 ]]
# [[-7.496794]]
# [[0.02632441]
#  [0.99965346]
#  [0.18013495]]
# [[-2.7810574]]
# [[-0.00516631]
#  [ 0.99998665]
#  [ 0.62987506]]
# [[-4.966461]]
# [[-0.05912506]
#  [ 0.9982506 ]
#  [ 1.0798651 ]]
# [[-6.3579116]]
# [[-0.1351722 ]
#  [ 0.99082214]
#  [ 1.528553  ]]
# [[-8.609941]]
# [[-0.23203641]
#  [ 0.9727071 ]
#  [ 1.9716697 ]]
# [[-9.88613]]
# [[-0.3468689]
#  [ 0.9379136]
#  [ 2.4012   ]]
# [[-4.8156695]]
# [[-0.4745585 ]
#  [ 0.88022393]
#  [ 2.8046353 ]]
# [[-3.414224]]
# [[-0.6073356]
#  [ 0.7944454]
#  [ 3.1648033]]
# [[-3.0280435]]
# [[-0.73504585]
#  [ 0.67801744]
#  [ 3.4606373 ]]
# [[-0.5862818]]
# [[-0.8520005]
#  [ 0.523541 ]
#  [ 3.8812082]]
# [[-0.04363012]]
# [[-0.9435405 ]
#  [ 0.33125716]
#  [ 4.2673197 ]]
# [[1.0864999]]
# [[-0.9946281 ]
#  [ 0.10351313]
#  [ 4.678737  ]]
# [[1.8687241]]
# [[-0.98904806]
#  [-0.14759386]
#  [ 5.0366807 ]]
# [[6.5556016]]
# [[-0.9173461 ]
#  [-0.39809054]
#  [ 5.2259855 ]]
# [[7.6719947]]
# [[-0.7833213 ]
#  [-0.62161696]
#  [ 5.2274175 ]]
# [[9.324452]]
# [[-0.6027401]
#  [-0.7979376]
#  [ 5.0612044]]
# [[11.505882]]
# [[-0.39750203]
#  [-0.9176013 ]
#  [ 4.762751  ]]
# [[15.294008]]
# [[-0.18892309]
#  [-0.9819919 ]
#  [ 4.3745503 ]]
# [[8.1976185]]
# [[ 0.00683733]
#  [-0.99997663]
#  [ 3.9380565 ]]
# [[4.992345]]
# [[ 0.18025044]
#  [-0.98362076]
#  [ 3.488074  ]]
# [[6.4597325]]
# [[ 0.32759675]
#  [-0.94481766]
#  [ 3.0503585 ]]
# [[9.184027]]
# [[ 0.44917887]
#  [-0.89344186]
#  [ 2.6417453 ]]
# [[9.648396]]
# [[ 0.5475463 ]
#  [-0.83677536]
#  [ 2.2716641 ]]
# [[13.073071]]
# [[ 0.62617165]
#  [-0.7796852 ]
#  [ 1.9440826 ]]
# [[9.524921]]
# [[ 0.6886309]
#  [-0.7251121]
#  [ 1.6593186]]
# [[4.605603]]
# [[ 0.73818326]
#  [-0.67460024]
#  [ 1.4154844 ]]
# [[10.345601]]
# [[ 0.77760655]
#  [-0.6287512 ]
#  [ 1.2095342 ]]
# [[6.904173]]
# [[ 0.80917615]
#  [-0.5875662 ]
#  [ 1.0379709 ]]
# [[4.291922]]
# [[ 0.834714  ]
#  [-0.55068374]
#  [ 0.8972962 ]]
# [[6.2701235]]
# [[ 0.85566133]
#  [-0.51753616]
#  [ 0.7842833 ]]
# [[5.79033]]
# [[ 0.87315315]
#  [-0.48744592]
#  [ 0.696131  ]]
# [[7.921546]]
# [[ 0.88808465]
#  [-0.4596799 ]
#  [ 0.63054675]]
# [[4.5960846]]
# [[ 0.90116554]
#  [-0.43347514]
#  [ 0.58578706]]
# [[7.7425027]]
# [[ 0.91296196]
#  [-0.40804467]
#  [ 0.5606809 ]]
# [[5.2203627]]
# [[ 0.9239255 ]
#  [-0.38257238]
#  [ 0.5546476 ]]
# [[9.024086]]
# [[ 0.9344116 ]
#  [-0.35619515]
#  [ 0.5677182 ]]
# [[7.2655993]]
# [[ 0.94468486]
#  [-0.3279795 ]
#  [ 0.60057175]]
# [[4.3163714]]
# [[ 0.9549115 ]
#  [-0.29689065]
#  [ 0.6545874 ]]
# [[7.9304867]]
# [[ 0.9651347 ]
#  [-0.2617539 ]
#  [ 0.73191965]]
# [[2.3002326]]
# [[ 0.9752253 ]
#  [-0.22121386]
#  [ 0.83560413]]
# [[1.413134]]
# [[ 0.98402655]
#  [-0.17802191]
#  [ 0.88166404]]
# [[2.2625484]]
# [[ 0.9920009 ]
#  [-0.12623096]
#  [ 1.0481474 ]]
# [[-7.8401256]]
# [[ 0.9955951 ]
#  [-0.09375688]
#  [ 0.6534741 ]]
# [[-3.610618]]
# [[ 0.9968227 ]
#  [-0.07965255]
#  [ 0.2831563 ]]
# [[-3.3792691]]
# [[ 0.9965104 ]
#  [-0.08346879]
#  [-0.07658285]]
# [[1.9421889]]
# [[ 0.9971165 ]
#  [-0.07588601]
#  [ 0.15214413]]
# [[3.5387645]]
# [[ 0.9984213 ]
#  [-0.05616789]
#  [ 0.39522952]]
# [[-0.17758346]]
# [[ 0.9992051 ]
#  [-0.03986381]
#  [ 0.32646632]]
# [[-2.159715]]
# [[ 0.99919826]
#  [-0.04003534]
#  [-0.00343129]]
# [[-2.2373343]]
# [[ 0.9983919 ]
#  [-0.05668872]
#  [-0.33345756]]
# [[0.7244108]]
# [[ 0.99754506]
#  [-0.07002752]
#  [-0.26731223]]
# [[3.0545712]]
# [[ 0.9974751 ]
#  [-0.07101687]
#  [-0.01983263]]
# [[-2.3765416]]
# [[ 0.9959768 ]
#  [-0.08961116]
#  [-0.37309504]]
# [[4.746643]]
# [[ 0.99532366]
#  [-0.0965959 ]
#  [-0.14030315]]
# [[-0.12327075]]
# [[ 0.9941403 ]
#  [-0.10809699]
#  [-0.23124045]]
# [[0.77393675]]
# [[ 0.993032  ]
#  [-0.11784507]
#  [-0.1962228 ]]
# [[5.5951257]]
# [[ 0.9931224 ]
#  [-0.11708078]
#  [ 0.01539364]]
# [[2.7058458]]
# [[ 0.99439037]
#  [-0.10577246]
#  [ 0.22758332]]
# [[-1.1025257]]
# [[ 0.9942994 ]
#  [-0.10662401]
#  [-0.01712465]]
# [[4.984598]]
# [[ 0.9953299 ]
#  [-0.09653135]
#  [ 0.20290756]]
# [[-1.9443567]]
# [[ 0.9945199 ]
#  [-0.10454762]
#  [-0.16114423]]
# [[2.8800213]]
# [[ 0.9948313 ]
#  [-0.10154152]
#  [ 0.06044497]]
# [[4.985297]]
# [[ 0.9961741 ]
#  [-0.08739069]
#  [ 0.28428873]]
# [[-0.40509742]]
# [[ 0.9968333 ]
#  [-0.07951898]
#  [ 0.157981  ]]
# [[-1.1505961]]
# [[ 0.9965313 ]
#  [-0.08321885]
#  [-0.07424776]]
# [[1.9984913]]
# [[ 0.9971769 ]
#  [-0.07508864]
#  [ 0.16311204]]
# [[1.2491914]]
# [[ 0.9981734 ]
#  [-0.06041405]
#  [ 0.29417455]]
# [[-1.3990061]]
# [[ 0.99828935]
#  [-0.05846675]
#  [ 0.03901333]]
# [[1.1501967]]
# [[ 0.9987445 ]
#  [-0.05009443]
#  [ 0.16769265]]
# [[-1.1739409]]
# [[ 0.9986267 ]
#  [-0.05238977]
#  [-0.04596943]]
# [[4.8878236]]
# [[ 0.9991316 ]
#  [-0.04166476]
#  [ 0.21473816]]
# [[0.64016306]]
# [[ 0.9996163 ]
#  [-0.02769766]
#  [ 0.2795143 ]]
# [[-4.386618]]
# [[ 0.9995571 ]
#  [-0.02975961]
#  [-0.04125905]]
# [[0.9570967]]
# [[ 0.9996681 ]
#  [-0.02576192]
#  [ 0.07998564]]
# [[2.3548963]]
# [[ 0.99997014]
#  [-0.00773166]
#  [ 0.36066446]]
# [[-1.7098649]]
# [[ 0.99999607]
#  [-0.00281221]
#  [ 0.0983862 ]]
# [[-2.9058347]]
# [[ 0.99991554]
#  [-0.01299804]
#  [-0.20372307]]
# [[-3.6458]]
# [[ 0.9992523 ]
#  [-0.03866216]
#  [-0.5134717 ]]
# [[2.3780096]]
# [[ 0.9987102 ]
#  [-0.05077354]
#  [-0.24246809]]
# [[0.70739865]]
# [[ 0.9982294 ]
#  [-0.05948208]
#  [-0.17443857]]
# [[0.03821325]]
# [[ 0.99753815]
#  [-0.07012551]
#  [-0.2133179 ]]
# [[5.114461]]
# [[ 0.9976562 ]
#  [-0.06842538]
#  [ 0.03408822]]
# [[0.95564914]]
# [[ 0.99806786]
#  [-0.06213314]
#  [ 0.12611681]]
# [[1.9922447]]
# [[ 0.9990646 ]
#  [-0.04324214]
#  [ 0.3783539 ]]
# [[0.65259695]]
# [[ 0.99977815]
#  [-0.0210635 ]
#  [ 0.4438117 ]]
# [[0.6535338]]
# [[0.9999863 ]
#  [0.00523725]
#  [0.5260444 ]]
# [[-3.2871068]]
# [[0.99986   ]
#  [0.01673495]
#  [0.2299726 ]]
# [[-4.273122]]
# [[ 0.9999039 ]
#  [ 0.01386139]
#  [-0.05747595]]
# [[-1.5292426]]
# [[ 1.0000000e+00]
#  [ 3.8321818e-05]
#  [-2.7646643e-01]]
# [[0.4800256]]
# [[ 0.99994814]
#  [-0.01018298]
#  [-0.20443395]]
# [[1.141714]]
# [[ 0.9999253 ]
#  [-0.01222372]
#  [-0.04081421]]
# [[-1.6165185]]
# [[ 0.99963963]
#  [-0.02684396]
#  [-0.2924599 ]]
# [[2.0433853]]
# [[ 0.9996225 ]
#  [-0.02747316]
#  [-0.01259264]]
# [[0.82008535]]
# [[ 0.99973583]
#  [-0.02298374]
#  [ 0.08981554]]
# [[4.50141]]
# [[ 0.9999905 ]
#  [-0.00435667]
#  [ 0.37257797]]
# [[-0.700687]]
# [[0.9999608 ]
#  [0.0088535 ]
#  [0.26420766]]
# [[-2.7353058]]
# [[ 0.99997264]
#  [ 0.00739585]
#  [-0.02915198]]
# [[-0.65057683]]
# [[ 0.9999991 ]
#  [ 0.00133627]
#  [-0.12119173]]
# [[3.3082538]]
# [[0.99994665]
#  [0.01032638]
#  [0.17981037]]
# [[-4.3666506]]
# [[ 0.9999889 ]
#  [ 0.00470416]
#  [-0.11244497]]
# [[1.5268943]]
# [[0.99994266]
#  [0.01070973]
#  [0.12011753]]
# [[-0.51894426]]
# [[0.99991256]
#  [0.01322487]
#  [0.05030807]]
# [[-3.1887562]]
# [[ 0.9999992 ]
#  [ 0.00123661]
#  [-0.23977304]]
# [[-1.996215]]
# [[ 0.9996704 ]
#  [-0.02567421]
#  [-0.5382776 ]]
# [[2.4018142]]
# [[ 0.9992569 ]
#  [-0.03854399]
#  [-0.257533  ]]
# [[1.0256138]]
# [[ 0.9989794 ]
#  [-0.04516811]
#  [-0.1325987 ]]
# [[2.7795048]]
# [[ 0.9992587 ]
#  [-0.03849777]
#  [ 0.13352546]]
# [[0.44950676]]
# [[ 0.9995529 ]
#  [-0.02989878]
#  [ 0.17207803]]
# [[1.3068342]]
# [[ 0.99992037]
#  [-0.01261899]
#  [ 0.345679  ]]
# [[2.138166]]
# [[0.9998158 ]
#  [0.01919026]
#  [0.636215  ]]
# [[-2.9925444]]
# [[0.9993258 ]
#  [0.03671363]
#  [0.3506079 ]]
# [[-4.859316]]
# [[0.9991748 ]
#  [0.04061791]
#  [0.07814336]]
# [[-1.5153033]]
# [[ 0.9993982 ]
#  [ 0.03468789]
#  [-0.11868846]]
# [[-1.04506]]
# [[ 0.99975306]
#  [ 0.02222134]
#  [-0.24943165]]
# [[1.1924403]]
# [[ 0.9998093 ]
#  [ 0.01952685]
#  [-0.05389935]]
# [[2.6005902]]
# [[0.9994698 ]
#  [0.03255954]
#  [0.26074603]]
# [[-2.2787275]]
# [[ 0.99949366]
#  [ 0.03181796]
#  [-0.01483443]]
# [[1.9129143]]
# [[0.9989134 ]
#  [0.04660461]
#  [0.2959661 ]]
# [[-2.18581]]
# [[0.99884015]
#  [0.04814878]
#  [0.03091943]]
# [[1.0289592]]
# [[0.9982461 ]
#  [0.05920159]
#  [0.22137478]]
# [[-4.0133767]]
# [[ 0.9983459 ]
#  [ 0.05749314]
#  [-0.03422379]]
# [[0.2681179]]
# [[0.9982017 ]
#  [0.05994461]
#  [0.04911363]]
# [[-0.6783952]]
# [[ 0.9982247 ]
#  [ 0.05956097]
#  [-0.00768731]]
# [[-1.0028963]]
# [[ 0.9985465 ]
#  [ 0.05389765]
#  [-0.11345115]]
# [[-3.6616158]]
# [[ 0.999378  ]
#  [ 0.03526498]
#  [-0.37302804]]
# [[0.6369455]]
# [[ 0.9997419 ]
#  [ 0.02271856]
#  [-0.25103724]]
# [[2.6424832]]
# [[0.9996615 ]
#  [0.02601777]
#  [0.06600156]]
# [[-1.7263453]]
# [[ 0.9998495 ]
#  [ 0.01734807]
#  [-0.17343669]]
# [[3.2359345]]
# [[0.9997041 ]
#  [0.02432505]
#  [0.1395746 ]]
# [[-2.7677627]]
# [[ 0.99985176]
#  [ 0.01721744]
#  [-0.14218174]]
# [[-0.6685804]]
# [[ 0.99998355]
#  [ 0.00574031]
#  [-0.22955547]]
# [[-1.3536562]]
# [[ 0.99987715]
#  [-0.01567377]
#  [-0.42829877]]
# [[2.95519]]
# [[ 0.99974287]
#  [-0.0226753 ]
#  [-0.1400542 ]]
# [[-2.4800935]]
# [[ 0.99896365]
#  [-0.04551442]
#  [-0.45706078]]
# [[5.5564175]]
# [[ 0.99848294]
#  [-0.05506191]
#  [-0.19119668]]
# [[1.9993103]]
# [[ 0.9986628 ]
#  [-0.05169643]
#  [ 0.06740329]]
# [[0.538405]]
# [[ 0.9989307]
#  [-0.0462332]
#  [ 0.1093916]]
# [[1.5347037]]
# [[ 0.9995194 ]
#  [-0.03099881]
#  [ 0.3049225 ]]
# [[-1.2313199]]
# [[ 0.999658  ]
#  [-0.02615184]
#  [ 0.09697528]]
# [[0.05337376]]
# [[ 0.9997605 ]
#  [-0.0218849 ]
#  [ 0.08536771]]
# [[0.52984667]]
# [[ 0.9998954 ]
#  [-0.01446465]
#  [ 0.14843091]]
# [[-0.12631774]]
# [[ 0.9999636 ]
#  [-0.0085332 ]
#  [ 0.11863465]]
# [[3.7303479]]
# [[0.99992704]
#  [0.01207817]
#  [0.41223463]]
# [[-4.7412815]]
# [[0.99983543]
#  [0.01814236]
#  [0.12129316]]
# [[0.08849138]]
# [[0.99967355]
#  [0.02554919]
#  [0.14817388]]
# [[1.3057404]]
# [[0.9990448 ]
#  [0.04369792]
#  [0.36319673]]
# [[0.38939333]]
# [[0.9977943 ]
#  [0.06638189]
#  [0.45437905]]
# [[-1.507617]]
# [[0.99677515]
#  [0.0802456 ]
#  [0.27802318]]
# [[-2.433465]]
# [[0.99662   ]
#  [0.08214951]
#  [0.03820728]]
# [[3.2276015]]
# [[0.99477875]
#  [0.10205512]
#  [0.3998193 ]]
# [[-2.7131133]]
# [[0.99384016]
#  [0.11082314]
#  [0.17636055]]
# [[-4.1265]]
# [[ 0.99406266]
#  [ 0.10880931]
#  [-0.04052185]]
# [[-1.1695747]]
# [[ 0.9947711 ]
#  [ 0.10212911]
#  [-0.13435118]]
# [[0.90367234]]
# [[0.99436635]
#  [0.10599802]
#  [0.0777964 ]]
# [[0.2786591]]
# Episode finished after 200 timesteps
